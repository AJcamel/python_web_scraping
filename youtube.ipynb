# %%
# 操作 browser 的 API
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# ChromeDriver 的下載管理工具
from webdriver_manager.chrome import ChromeDriverManager

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

# 整理 json 使用的工具
import json

# 執行 command 的時候用的
import os

# 子處理程序，用來取代 os.system 的功能
import subprocess

# 下載檔案的工具
import wget

# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
my_options.add_argument("--lang=zh-TW")  #設定為正體中文

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options
)

# 建立儲存圖片、影片的資料夾
folderPath = 'youtube'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# 放置爬取的資料
listData = []

# %%
# 走訪頁面
def visit():
    driver.get('https://www.youtube.com/')

# 輸入關鍵字
def search():
    # 輸入名稱
    txtInput = driver.find_element(
        By.CSS_SELECTOR,
        "input#search"
    )
    txtInput.send_keys("五月天")

    # 等待一下
    sleep(1)

    # 送出表單資料
    txtInput.submit()

    # 等待一下
    sleep(2)

# 篩選 (選項)
def filterFunc():
    try:
        # 等待篩選元素
        WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (
                    By.CSS_SELECTOR,
                    'button[aria-label=搜尋篩選器][title][style]'
                )
            )
        )

        #按下篩選元素，使項目浮現
        driver.find_element(
            By.CSS_SELECTOR,
            'button[aria-label=搜尋篩選器][title][style]'
        ).click()

        # 等待一下
        sleep(2)

        # 按下選擇的項目
        driver.find_elements(
            By.CSS_SELECTOR,
            'ytd-search-filter-renderer a#endpoint'
        )[10].click()

        # 等待一下
        sleep(3)
        
    except TimeoutException:
        print('等待逾時')

# 滾動頁面
def scroll():
    innerHeight = 0
    offset = 0
    count = 0
    limit = 3

    
    # 在捲動到沒有元素動態產生前，持續捲動
    while count <= limit:
        # 每次移動高度
        offset = driver.execute_script(
            'return document.documentElement.scrollHeight;'
        )

        # 捲軸往下滑動
        driver.execute_script(f'''
            window.scrollTo({{
                top: {offset},
                behavior: 'smooth'
            }});
        ''') 

        # (重要)強制等待
        sleep(3)

        # 透過執行 js 語法來取得捲動後的當前總高度
        innerHeight = driver.execute_script(
            'return document.documentElement.scrollHeight;'
        )

        # 經過計算，如果滾動距離(offset)
        # 大於等於視窗內部總高度(innerHeight)
        # 代表已經到底了
        if offset == innerHeight:
            count += 1

        # 為了實驗功能，捲動超過一定的距離，就結束程式
        if offset >= 600:
            break

# 分析頁面元素資訊
def parse():
    # 使用全域變數
    global listData

    # 清空存放資料的變數
    listData.clear()

    # 取得主要元素的集合
    elements = driver.find_elements(
        By.CSS_SELECTOR,
        'ytd-video-renderer.style-scope.ytd-item-section-renderer'
    )

    # 逐一檢視元素
    for elm in elements:
        # 印出分隔文字
        print("=" * 30)

        # 取得圖片連結
        img = elm.find_element(
            By.CSS_SELECTOR,
            'a#thumbnail img'
        )
        imgSrc = img.get_attribute('src')
        print(imgSrc)

        # 取得超連結
        a = elm.find_element(
            By.CSS_SELECTOR,
            'a#video-title'
        )
        aTitle = a.get_attribute('innerText')
        print('aTitle') # 超連結內文

        # 取得 YouTube 連結
        aLink = a.get_attribute('href')
        print(aLink)

        # 取得 影音 ID
        ssr = ''
        if 'shorts' in aLink:
            ssr = '/shorts/'
        else:
            ssr = 'v='
        youtube_id = aLink.split(ssr)[1]
        youtube_id = youtube_id.split('&pp')[0]
        print(youtube_id)

        # 放資料到 list 中
        listData.append({
            "id": youtube_id,
            "title": aTitle,
            "link": aLink,
            "img": imgSrc
        })

# 將 list 存成 json
def saveJson():
    with open(f"{folderPath}/youtube.json", "w", encoding="utf-8") as file:
        file.write(
            json.dumps(listData, ensure_ascii=False, indent=4)
        )

# 關閉瀏覽器
def close():
    driver.quit()

# %%
visit()
search()
filterFunc()
scroll()
parse()
saveJson()
# Out:
# ==============================
# https://i.ytimg.com/vi/jBJXMcjr63M/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCgfxKXtjrZ1U6C8iR_rEqbjWXTLA
# aTitle
# https://www.youtube.com/watch?v=jBJXMcjr63M&pp=ygUJ5LqU5pyI5aSp
# jBJXMcjr63M
# ==============================
# https://i.ytimg.com/vi/r48RNE2T6ZY/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAAAJUIOyFVdt6DOeUC2dGHXVI2qQ
# aTitle
# https://www.youtube.com/watch?v=r48RNE2T6ZY&pp=ygUJ5LqU5pyI5aSp
# r48RNE2T6ZY
# ==============================
# https://i.ytimg.com/vi/qX2GsMj7154/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDUlwp9OolmKzO6TDNusdVEW8ghyw
# aTitle
# https://www.youtube.com/watch?v=qX2GsMj7154&pp=ygUJ5LqU5pyI5aSp
# qX2GsMj7154
# ==============================
# https://i.ytimg.com/vi/1j_mpwKmlJg/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBoeJnLNcYOOTQ_huV4jHU9SexP-g
# aTitle
# https://www.youtube.com/watch?v=1j_mpwKmlJg&pp=ygUJ5LqU5pyI5aSp
# 1j_mpwKmlJg
# ==============================
# https://i.ytimg.com/vi/Fn7NLWHJw4s/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAZimrTtFP1Q577097LhKqCRsuy0w
# aTitle
# https://www.youtube.com/watch?v=Fn7NLWHJw4s&pp=ygUJ5LqU5pyI5aSp
# Fn7NLWHJw4s
# ==============================
# https://i.ytimg.com/vi/pd3eV-SG23E/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB3tEJ1EEujaZYoNcV2HcvtTQPMaA
# aTitle
# https://www.youtube.com/watch?v=pd3eV-SG23E&pp=ygUJ5LqU5pyI5aSp
# pd3eV-SG23E
# ==============================
# https://i.ytimg.com/vi/FpYPmkfynIo/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDsHfBa8Qw6EQlYZ-hZNPFYrngahA
# aTitle
# https://www.youtube.com/watch?v=FpYPmkfynIo&pp=ygUJ5LqU5pyI5aSp
# FpYPmkfynIo
# ==============================
# https://i.ytimg.com/vi/_o0oeyCtoFA/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDWDYG_aHMfrLie8qLTmd1HIrBF5w
# aTitle
# https://www.youtube.com/watch?v=_o0oeyCtoFA&pp=ygUJ5LqU5pyI5aSp
# _o0oeyCtoFA
# ==============================
# https://i.ytimg.com/vi/V9sWPHGbESM/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDXMl66t4nFldSFxGSbDSiGLX2S3w
# aTitle
# https://www.youtube.com/watch?v=V9sWPHGbESM&pp=ygUJ5LqU5pyI5aSp
# V9sWPHGbESM
# ==============================
# https://i.ytimg.com/vi/olGod8i1j1o/hqdefault.jpg?sqp=-oaymwEcCOADEI4CSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBHZMhyLnOAjd-Z57HNFSkW_5n0xQ
# aTitle
# https://www.youtube.com/watch?v=olGod8i1j1o&pp=ygUJ5LqU5pyI5aSp
# olGod8i1j1o
# ==============================
# https://i.ytimg.com/vi/5VUUGZ1-nlY/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBF14HtxroeX3hq_KX2UkSm80XGdg
# aTitle
# https://www.youtube.com/watch?v=5VUUGZ1-nlY&pp=ygUJ5LqU5pyI5aSp
# 5VUUGZ1-nlY
# ==============================
# https://i.ytimg.com/vi/_s8Iot-uo7s/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDzBCJYTt-7YwWjywGXWEads3hsWg
# aTitle
# https://www.youtube.com/watch?v=_s8Iot-uo7s&pp=ygUJ5LqU5pyI5aSp
# _s8Iot-uo7s
# ==============================
# https://i.ytimg.com/vi/d3JVkes8o4k/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBjfimuvGfDwBt2ilkarjkJJ0lb_g
# aTitle
# https://www.youtube.com/watch?v=d3JVkes8o4k&pp=ygUJ5LqU5pyI5aSp
# d3JVkes8o4k
# ==============================
# https://i.ytimg.com/vi/lvDa3r1pNuE/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCXZqo2lfbqgYtJkqTwbF5W0JSLvA
# aTitle
# https://www.youtube.com/watch?v=lvDa3r1pNuE&pp=ygUJ5LqU5pyI5aSp
# lvDa3r1pNuE
# ==============================
# https://i.ytimg.com/vi/YKiMrg6rgYQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAQ6Yhvv9tp8bWnG8auRqPex6Sisg
# aTitle
# https://www.youtube.com/watch?v=YKiMrg6rgYQ&pp=ygUJ5LqU5pyI5aSp
# YKiMrg6rgYQ
# ==============================
# https://i.ytimg.com/vi/rS8HqJy1UPs/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCfgEd12uhTx7ugzg4mudkn_EnDTQ
# aTitle
# https://www.youtube.com/watch?v=rS8HqJy1UPs&pp=ygUJ5LqU5pyI5aSp
# rS8HqJy1UPs
# ==============================
# https://i.ytimg.com/vi/K8KrHP5flRo/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBlkDz_s7zPQVBWWGb0oNAXioo6lA
# aTitle
# https://www.youtube.com/watch?v=K8KrHP5flRo&pp=ygUJ5LqU5pyI5aSp
# K8KrHP5flRo
# ==============================
# https://i.ytimg.com/vi/R2s-H_crYkc/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCY8keJWng9O6sIyPGXb9dL1JLOVg
# aTitle
# https://www.youtube.com/watch?v=R2s-H_crYkc&pp=ygUJ5LqU5pyI5aSp
# R2s-H_crYkc
# ==============================
# https://i.ytimg.com/vi/5h6Ak4LzFyI/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAGz1BOYy57JbqKhuH_m3JVxKkeuw
# aTitle
# https://www.youtube.com/watch?v=5h6Ak4LzFyI&pp=ygUJ5LqU5pyI5aSp
# 5h6Ak4LzFyI
# ==============================
# https://i.ytimg.com/vi/MBpDwpUj9-M/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLD-UlH3v5sw5YVW66kEawqjF0C1Dw
# aTitle
# https://www.youtube.com/watch?v=MBpDwpUj9-M&pp=ygUJ5LqU5pyI5aSp
# MBpDwpUj9-M
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=w_OfGctVLdE&pp=ygUJ5LqU5pyI5aSp
# w_OfGctVLdE
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=WIBFnmY2YrA&pp=ygUJ5LqU5pyI5aSp
# WIBFnmY2YrA
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=LtunmrE1i5I&pp=ygUJ5LqU5pyI5aSp
# LtunmrE1i5I
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=uCFLjXE2LtA&pp=ygUJ5LqU5pyI5aSp
# uCFLjXE2LtA
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=Jv3zvWZlXkk&pp=ygUJ5LqU5pyI5aSp
# Jv3zvWZlXkk
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=EitgfC3gg7M&pp=ygUJ5LqU5pyI5aSp
# EitgfC3gg7M
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=lUCa4e5Mkrc&pp=ygUJ5LqU5pyI5aSp
# lUCa4e5Mkrc
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=i_ZHOGNEaJM&pp=ygUJ5LqU5pyI5aSp
# i_ZHOGNEaJM
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=RTUwaCImChM&pp=ygUJ5LqU5pyI5aSp
# RTUwaCImChM
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=97axrS3Npxk&pp=ygUJ5LqU5pyI5aSp
# 97axrS3Npxk
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=IBIiRY8_2J0&pp=ygUJ5LqU5pyI5aSp
# IBIiRY8_2J0
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=EZxVmhM6UpE&pp=ygUJ5LqU5pyI5aSp
# EZxVmhM6UpE
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=jGqpz3stgzY&pp=ygUJ5LqU5pyI5aSp
# jGqpz3stgzY
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=yarOcdANK50&pp=ygUJ5LqU5pyI5aSp
# yarOcdANK50
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=NbtaaTfINaM&pp=ygUJ5LqU5pyI5aSp
# NbtaaTfINaM
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=nIe3FLKNwTA&pp=ygUJ5LqU5pyI5aSp
# nIe3FLKNwTA
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=U-C0Z3ys_C8&pp=ygUJ5LqU5pyI5aSp
# U-C0Z3ys_C8
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=VnhoRZ57kSY&pp=ygUJ5LqU5pyI5aSp
# VnhoRZ57kSY
# ==============================
# None
# aTitle
# https://www.youtube.com/watch?v=ptmxLFZkoZ4&pp=ygUJ5LqU5pyI5aSp
# ptmxLFZkoZ4

# %%
close()

# %%
# 下載
def download():
    # 確認 yt-dlp 是否存在
    if not os.path.exists('./yt-dlp.exe'):
        print('[下載 yt-dlp]')
        wget.download(
            'https://github.com/yt-dlp/yt-dlp/releases/latest/download/yt-dlp.exe',
            './yt-dlp.exe'
        )

    # 開啟 json 檔案
    with open(f"{folderPath}/youtube.json", "r", encoding="utf-8") as file:
        #取得 json 字串
        strJson = file.read()

    # 將 json 轉成 list (裡面是 dict 集合)
    listResult = json.loads(strJson)

    # 下載所有檔案
    for index, obj in enumerate(listResult):
        if index == 3:
            break

        print(f"正在下載: {obj['link']}")

        # 定義指令
        cmd = [
            './yt-dlp.exe',
            obj['link'],
            '-f',
            'b[ext=mp4]',
            '-o',
            f'{folderPath}/%(id)s.%(ext)s'
        ]

        # 執行指令，並取得回傳結果 (subprocess 物件)
        obj_sp = subprocess.run(cmd)
        
        # 判斷指令行是否正常 (returncode == 0 代表正常)
        if obj_sp.returncode == 0:
            print('下載成功')
        else:
            print('下載失敗')
        
download()
# Out:
# [下載 yt-dlp]
# 正在下載: https://www.youtube.com/watch?v=jBJXMcjr63M&pp=ygUJ5LqU5pyI5aSp
# 下載成功
# 正在下載: https://www.youtube.com/watch?v=r48RNE2T6ZY&pp=ygUJ5LqU5pyI5aSp
# 下載成功
# 正在下載: https://www.youtube.com/watch?v=qX2GsMj7154&pp=ygUJ5LqU5pyI5aSp
# 下載成功
