# %%
import pyautogui
from time import sleep, time
import keyboard
from IPython.display import clear_output

# %%
'''
自動點擊網頁版鋼琴鍵

補充: 此時網頁應該明顯出現在桌面上，不然會有判斷錯誤的問題 
'''

# https://www.autopiano.cn/zh-TW/post/11578

# 設定每一個動作，都暫停若干秒
pyautogui.PAUSE = 0.5

# 比對所有圖片，取得顯示在桌面的圖片物件 (pillow / PIL Image)
btn_11_loc = pyautogui.locateOnScreen('images/11.png', confidence=0.9)
btn_22_loc = pyautogui.locateOnScreen('images/22.png', confidence=0.9)
btn_33_loc = pyautogui.locateOnScreen('images/33.png', confidence=0.9)
btn_44_loc = pyautogui.locateOnScreen('images/44.png', confidence=0.9)
btn_55_loc = pyautogui.locateOnScreen('images/55.png', confidence=0.9)
btn_66_loc = pyautogui.locateOnScreen('images/66.png', confidence=0.9)

# 取得每一個圖片的中心點
btn_11_pt = pyautogui.center(btn_11_loc)
btn_22_pt = pyautogui.center(btn_22_loc)
btn_33_pt = pyautogui.center(btn_33_loc)
btn_44_pt = pyautogui.center(btn_44_loc)
btn_55_pt = pyautogui.center(btn_55_loc)
btn_66_pt = pyautogui.center(btn_66_loc)

# 按下 
pyautogui.click(btn_11_pt.x, btn_11_pt.y)
pyautogui.click(btn_11_pt.x, btn_11_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_66_pt.x, btn_66_pt.y)
pyautogui.click(btn_66_pt.x, btn_66_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
sleep(0.5)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_22_pt.x, btn_22_pt.y)
pyautogui.click(btn_22_pt.x, btn_22_pt.y)
pyautogui.click(btn_11_pt.x, btn_11_pt.y)
sleep(0.5)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_22_pt.x, btn_22_pt.y)
sleep(0.5)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_22_pt.x, btn_22_pt.y)
sleep(0.5)
pyautogui.click(btn_11_pt.x, btn_11_pt.y)
pyautogui.click(btn_11_pt.x, btn_11_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
pyautogui.click(btn_66_pt.x, btn_66_pt.y)
pyautogui.click(btn_66_pt.x, btn_66_pt.y)
pyautogui.click(btn_55_pt.x, btn_55_pt.y)
sleep(0.5)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_44_pt.x, btn_44_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_33_pt.x, btn_33_pt.y)
pyautogui.click(btn_22_pt.x, btn_22_pt.y)
pyautogui.click(btn_22_pt.x, btn_22_pt.y)
pyautogui.click(btn_11_pt.x, btn_11_pt.y)
