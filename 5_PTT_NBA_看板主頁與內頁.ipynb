# %%
# 匯入套件
from bs4 import BeautifulSoup as bs
import requests as req
from pprint import pprint

# %%
# 取得新聞列表
url = "https://www.ptt.cc/bbs/NBA/index.html" 

# 用 requests 的 get 方法把網頁抓下來
res = req.get(url) 

# 指定 lxml 作為解析器
soup = bs(res.text, "lxml") 

# 建立 list 來放置列表資訊
list_posts = []

# %%
# 建立 list 來放置列表資訊
list_posts = []

# 起始頁數
init_page = 6501

# 最新頁數
latest_page = 6503


for page in range(init_page, latest_page + 1):
    # 取得新聞列表
    url = "https://www.ptt.cc/bbs/NBA/index.html" 

    # 用 requests 的 get 方法把網頁抓下來
    res = req.get(url) 

    # 指定 lxml 作為解析器
    soup = bs(res.text, "lxml") 

    # 取得 列表 的文字與超連結
    for a in soup.select('div.r-ent div.title a[href]'):
        print(a.get_text())
        print(a['href'])

        # 加入列表資訊
        list_posts.append({
            'title': a.get_text(),
            'link': 'https://www.ptt.cc' + a['href']
        })

pprint(list_posts)
# Out:
# [BOX ] Spurs 104:113 Clippers
# /bbs/NBA/M.1730785662.A.846.html
# [花邊] Carrington與Green交談，Poole將其拉開
# /bbs/NBA/M.1730786282.A.2C8.html
# [情報] NBA Standings (Nov. 05, 2024)
# /bbs/NBA/M.1730786751.A.BF8.html
# [花邊] JeffGreen成為NBA有過最多隊友的男人
# /bbs/NBA/M.1730786814.A.388.html
# [情報] 雷霆開季7-0的秘密：防守
# /bbs/NBA/M.1730788066.A.C47.html
# [情報] Harden:Ballmer開玩笑說要把球場拆了重新蓋一座
# /bbs/NBA/M.1730792284.A.F15.html
# [討論] NCAA開幕戰 多位熱門待選秀表現出色
# /bbs/NBA/M.1730797832.A.0B2.html
# [討論] Gradey Dick 悟性這麼高嗎!?
# /bbs/NBA/M.1730801732.A.848.html
# [花邊] 77 ：我跟Mathurin說要講垃圾話怎不早說
# /bbs/NBA/M.1730806232.A.257.html
# [新聞] 轉戰76人首秀拿15分 喬治直言有點「生鏽
# /bbs/NBA/M.1730808180.A.BF3.html
# [情報] 緯來NBA轉播異動
# /bbs/NBA/M.1730808434.A.387.html
# [新聞] 第10個賽季仍開發新武器 Jokic外線準度震驚隊友
# /bbs/NBA/M.1730812743.A.873.html
# [情報] 96-97賽季迄今各季三分出手最多球隊
# /bbs/NBA/M.1730813567.A.2AA.html
# [情報] 尼克簽下Boo Buie
# /bbs/NBA/M.1730819306.A.61B.html
# [花邊] Russell Westbrook生涯抄截獨居史上第17位
# /bbs/NBA/M.1730821015.A.D65.html
# [情報] 第3週 Power Rankings 戰力排行榜
# /bbs/NBA/M.1730821559.A.251.html
# [花邊] VC的退休影片逐漸迷因化
# /bbs/NBA/M.1730823083.A.D16.html
# [公告] 板規10.1
# /bbs/NBA/M.1728456762.A.CB2.html
# [情報] 2024-25 NBA Schedule (10/23 ~ 11/30)
# /bbs/NBA/M.1729385774.A.DCB.html
# Fw: [公告] 請留意新註冊帳號使用信件詐騙**發錢**
# /bbs/NBA/M.1730556815.A.577.html
# [公告] NBA 板 開始舉辦樂透!
# /bbs/NBA/M.1730778452.A.31E.html
# [情報] NBA Standings (Nov. 05, 2024)
# /bbs/NBA/M.1730786751.A.BF8.html
# [BOX ] Spurs 104:113 Clippers
# /bbs/NBA/M.1730785662.A.846.html
# [花邊] Carrington與Green交談，Poole將其拉開
# /bbs/NBA/M.1730786282.A.2C8.html
# [情報] NBA Standings (Nov. 05, 2024)
# /bbs/NBA/M.1730786751.A.BF8.html
# [花邊] JeffGreen成為NBA有過最多隊友的男人
# /bbs/NBA/M.1730786814.A.388.html
# [情報] 雷霆開季7-0的秘密：防守
# /bbs/NBA/M.1730788066.A.C47.html
# [情報] Harden:Ballmer開玩笑說要把球場拆了重新蓋一座
# /bbs/NBA/M.1730792284.A.F15.html
# [討論] NCAA開幕戰 多位熱門待選秀表現出色
# /bbs/NBA/M.1730797832.A.0B2.html
# [討論] Gradey Dick 悟性這麼高嗎!?
# /bbs/NBA/M.1730801732.A.848.html
# [花邊] 77 ：我跟Mathurin說要講垃圾話怎不早說
# /bbs/NBA/M.1730806232.A.257.html
# [新聞] 轉戰76人首秀拿15分 喬治直言有點「生鏽
# /bbs/NBA/M.1730808180.A.BF3.html
# [情報] 緯來NBA轉播異動
# /bbs/NBA/M.1730808434.A.387.html
# [新聞] 第10個賽季仍開發新武器 Jokic外線準度震驚隊友
# /bbs/NBA/M.1730812743.A.873.html
# [情報] 96-97賽季迄今各季三分出手最多球隊
# /bbs/NBA/M.1730813567.A.2AA.html
# [情報] 尼克簽下Boo Buie
# /bbs/NBA/M.1730819306.A.61B.html
# [花邊] Russell Westbrook生涯抄截獨居史上第17位
# /bbs/NBA/M.1730821015.A.D65.html
# [情報] 第3週 Power Rankings 戰力排行榜
# /bbs/NBA/M.1730821559.A.251.html
# [花邊] VC的退休影片逐漸迷因化
# /bbs/NBA/M.1730823083.A.D16.html
# [公告] 板規10.1
# /bbs/NBA/M.1728456762.A.CB2.html
# [情報] 2024-25 NBA Schedule (10/23 ~ 11/30)
# /bbs/NBA/M.1729385774.A.DCB.html
# Fw: [公告] 請留意新註冊帳號使用信件詐騙**發錢**
# /bbs/NBA/M.1730556815.A.577.html
# [公告] NBA 板 開始舉辦樂透!
# /bbs/NBA/M.1730778452.A.31E.html
# [情報] NBA Standings (Nov. 05, 2024)
# /bbs/NBA/M.1730786751.A.BF8.html
# [BOX ] Spurs 104:113 Clippers
# /bbs/NBA/M.1730785662.A.846.html
# [花邊] Carrington與Green交談，Poole將其拉開
# /bbs/NBA/M.1730786282.A.2C8.html
# [情報] NBA Standings (Nov. 05, 2024)
# /bbs/NBA/M.1730786751.A.BF8.html
# [花邊] JeffGreen成為NBA有過最多隊友的男人
# /bbs/NBA/M.1730786814.A.388.html
# [情報] 雷霆開季7-0的秘密：防守
# /bbs/NBA/M.1730788066.A.C47.html
# [情報] Harden:Ballmer開玩笑說要把球場拆了重新蓋一座
# /bbs/NBA/M.1730792284.A.F15.html
# [討論] NCAA開幕戰 多位熱門待選秀表現出色
# /bbs/NBA/M.1730797832.A.0B2.html
# [討論] Gradey Dick 悟性這麼高嗎!?
# /bbs/NBA/M.1730801732.A.848.html
# [花邊] 77 ：我跟Mathurin說要講垃圾話怎不早說
# /bbs/NBA/M.1730806232.A.257.html
# [新聞] 轉戰76人首秀拿15分 喬治直言有點「生鏽
# /bbs/NBA/M.1730808180.A.BF3.html
# [情報] 緯來NBA轉播異動
# /bbs/NBA/M.1730808434.A.387.html
# [新聞] 第10個賽季仍開發新武器 Jokic外線準度震驚隊友
# /bbs/NBA/M.1730812743.A.873.html
# [情報] 96-97賽季迄今各季三分出手最多球隊
# /bbs/NBA/M.1730813567.A.2AA.html
# [情報] 尼克簽下Boo Buie
# /bbs/NBA/M.1730819306.A.61B.html
# [花邊] Russell Westbrook生涯抄截獨居史上第17位
# /bbs/NBA/M.1730821015.A.D65.html
# [情報] 第3週 Power Rankings 戰力排行榜
# /bbs/NBA/M.1730821559.A.251.html
# [花邊] VC的退休影片逐漸迷因化
# /bbs/NBA/M.1730823083.A.D16.html
# [公告] 板規10.1
# /bbs/NBA/M.1728456762.A.CB2.html
# [情報] 2024-25 NBA Schedule (10/23 ~ 11/30)
# /bbs/NBA/M.1729385774.A.DCB.html
# Fw: [公告] 請留意新註冊帳號使用信件詐騙**發錢**
# /bbs/NBA/M.1730556815.A.577.html
# [公告] NBA 板 開始舉辦樂透!
# /bbs/NBA/M.1730778452.A.31E.html
# [情報] NBA Standings (Nov. 05, 2024)
# /bbs/NBA/M.1730786751.A.BF8.html
# [{'link': 'https://www.ptt.cc/bbs/NBA/M.1730785662.A.846.html',
#   'title': '[BOX ] Spurs 104:113 Clippers'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786282.A.2C8.html',
#   'title': '[花邊] Carrington與Green交談，Poole將其拉開'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786751.A.BF8.html',
#   'title': '[情報] NBA Standings (Nov. 05, 2024)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786814.A.388.html',
#   'title': '[花邊] JeffGreen成為NBA有過最多隊友的男人'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730788066.A.C47.html',
#   'title': '[情報] 雷霆開季7-0的秘密：防守'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730792284.A.F15.html',
#   'title': '[情報] Harden:Ballmer開玩笑說要把球場拆了重新蓋一座'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730797832.A.0B2.html',
#   'title': '[討論] NCAA開幕戰 多位熱門待選秀表現出色'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730801732.A.848.html',
#   'title': '[討論] Gradey Dick 悟性這麼高嗎!?'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730806232.A.257.html',
#   'title': '[花邊] 77 ：我跟Mathurin說要講垃圾話怎不早說'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730808180.A.BF3.html',
#   'title': '[新聞] 轉戰76人首秀拿15分 喬治直言有點「生鏽'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730808434.A.387.html',
#   'title': '[情報] 緯來NBA轉播異動'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730812743.A.873.html',
#   'title': '[新聞] 第10個賽季仍開發新武器 Jokic外線準度震驚隊友'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730813567.A.2AA.html',
#   'title': '[情報] 96-97賽季迄今各季三分出手最多球隊'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730819306.A.61B.html',
#   'title': '[情報] 尼克簽下Boo Buie'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730821015.A.D65.html',
#   'title': '[花邊] Russell Westbrook生涯抄截獨居史上第17位'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730821559.A.251.html',
#   'title': '[情報] 第3週 Power Rankings 戰力排行榜 '},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730823083.A.D16.html',
#   'title': '[花邊] VC的退休影片逐漸迷因化'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1728456762.A.CB2.html',
#   'title': '[公告] 板規10.1'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1729385774.A.DCB.html',
#   'title': '[情報] 2024-25 NBA Schedule (10/23 ~ 11/30)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730556815.A.577.html',
#   'title': 'Fw: [公告] 請留意新註冊帳號使用信件詐騙**發錢**'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730778452.A.31E.html',
#   'title': '[公告] NBA 板 開始舉辦樂透!'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786751.A.BF8.html',
#   'title': '[情報] NBA Standings (Nov. 05, 2024)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730785662.A.846.html',
#   'title': '[BOX ] Spurs 104:113 Clippers'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786282.A.2C8.html',
#   'title': '[花邊] Carrington與Green交談，Poole將其拉開'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786751.A.BF8.html',
#   'title': '[情報] NBA Standings (Nov. 05, 2024)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786814.A.388.html',
#   'title': '[花邊] JeffGreen成為NBA有過最多隊友的男人'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730788066.A.C47.html',
#   'title': '[情報] 雷霆開季7-0的秘密：防守'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730792284.A.F15.html',
#   'title': '[情報] Harden:Ballmer開玩笑說要把球場拆了重新蓋一座'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730797832.A.0B2.html',
#   'title': '[討論] NCAA開幕戰 多位熱門待選秀表現出色'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730801732.A.848.html',
#   'title': '[討論] Gradey Dick 悟性這麼高嗎!?'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730806232.A.257.html',
#   'title': '[花邊] 77 ：我跟Mathurin說要講垃圾話怎不早說'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730808180.A.BF3.html',
#   'title': '[新聞] 轉戰76人首秀拿15分 喬治直言有點「生鏽'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730808434.A.387.html',
#   'title': '[情報] 緯來NBA轉播異動'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730812743.A.873.html',
#   'title': '[新聞] 第10個賽季仍開發新武器 Jokic外線準度震驚隊友'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730813567.A.2AA.html',
#   'title': '[情報] 96-97賽季迄今各季三分出手最多球隊'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730819306.A.61B.html',
#   'title': '[情報] 尼克簽下Boo Buie'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730821015.A.D65.html',
#   'title': '[花邊] Russell Westbrook生涯抄截獨居史上第17位'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730821559.A.251.html',
#   'title': '[情報] 第3週 Power Rankings 戰力排行榜 '},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730823083.A.D16.html',
#   'title': '[花邊] VC的退休影片逐漸迷因化'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1728456762.A.CB2.html',
#   'title': '[公告] 板規10.1'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1729385774.A.DCB.html',
#   'title': '[情報] 2024-25 NBA Schedule (10/23 ~ 11/30)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730556815.A.577.html',
#   'title': 'Fw: [公告] 請留意新註冊帳號使用信件詐騙**發錢**'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730778452.A.31E.html',
#   'title': '[公告] NBA 板 開始舉辦樂透!'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786751.A.BF8.html',
#   'title': '[情報] NBA Standings (Nov. 05, 2024)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730785662.A.846.html',
#   'title': '[BOX ] Spurs 104:113 Clippers'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786282.A.2C8.html',
#   'title': '[花邊] Carrington與Green交談，Poole將其拉開'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786751.A.BF8.html',
#   'title': '[情報] NBA Standings (Nov. 05, 2024)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786814.A.388.html',
#   'title': '[花邊] JeffGreen成為NBA有過最多隊友的男人'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730788066.A.C47.html',
#   'title': '[情報] 雷霆開季7-0的秘密：防守'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730792284.A.F15.html',
#   'title': '[情報] Harden:Ballmer開玩笑說要把球場拆了重新蓋一座'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730797832.A.0B2.html',
#   'title': '[討論] NCAA開幕戰 多位熱門待選秀表現出色'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730801732.A.848.html',
#   'title': '[討論] Gradey Dick 悟性這麼高嗎!?'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730806232.A.257.html',
#   'title': '[花邊] 77 ：我跟Mathurin說要講垃圾話怎不早說'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730808180.A.BF3.html',
#   'title': '[新聞] 轉戰76人首秀拿15分 喬治直言有點「生鏽'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730808434.A.387.html',
#   'title': '[情報] 緯來NBA轉播異動'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730812743.A.873.html',
#   'title': '[新聞] 第10個賽季仍開發新武器 Jokic外線準度震驚隊友'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730813567.A.2AA.html',
#   'title': '[情報] 96-97賽季迄今各季三分出手最多球隊'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730819306.A.61B.html',
#   'title': '[情報] 尼克簽下Boo Buie'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730821015.A.D65.html',
#   'title': '[花邊] Russell Westbrook生涯抄截獨居史上第17位'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730821559.A.251.html',
#   'title': '[情報] 第3週 Power Rankings 戰力排行榜 '},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730823083.A.D16.html',
#   'title': '[花邊] VC的退休影片逐漸迷因化'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1728456762.A.CB2.html',
#   'title': '[公告] 板規10.1'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1729385774.A.DCB.html',
#   'title': '[情報] 2024-25 NBA Schedule (10/23 ~ 11/30)'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730556815.A.577.html',
#   'title': 'Fw: [公告] 請留意新註冊帳號使用信件詐騙**發錢**'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730778452.A.31E.html',
#   'title': '[公告] NBA 板 開始舉辦樂透!'},
#  {'link': 'https://www.ptt.cc/bbs/NBA/M.1730786751.A.BF8.html',
#   'title': '[情報] NBA Standings (Nov. 05, 2024)'}]

# %%
# 走訪每一個 a link，整合網頁內文
for index, obj in enumerate(list_posts):
    res_ = req.get(obj['link'])
    soup_ = bs(res_.text, "lxml")

    # 去掉 div.article-metaline (作者、標題、時間…等)
    for div in soup_.select('div[class^=article-metaline]'):
        div.decompose()

    # 去掉 div.push (推文: 推、→、噓) (判斷元素是否存在)
    if len(soup_.select('div.push')) > 0:
        for div in soup_.select('div.push'):
            div.decompose()

    # 取得實際需要的內容 (類似 JavaScript 的 innerHTML)
    html = soup_.select_one('div#main-content').decode_contents() 

    # 整合到列表資訊的變數當中
    list_posts[index]['html'] = html

pprint(list_posts)
# Out:
# [{'html': '\n'
#           '<a href="https://x.com/NBA/status/1823042610707210357" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/NBA/status/1823042610707210357</a>\n'
#           '\n'
#           'Greens all day\n'
#           '\n'
#           'The top 5 three-point shooters in #NBA2K25!\n'
#           '\n'
#           '2k25三分能力值Top5的球員\n'
#           '\n'
#           'Curry - 99\n'
#           'Allen - 93\n'
#           'KD - 92\n'
#           'KT - 89\n'
#           'Conley - 89\n'
#           '\n'
#           '<a href="http://i.imgur.com/JMg3O1O.jpg" rel="noreferrer noopener '
#           'nofollow" target="_blank">http://i.imgur.com/JMg3O1O.jpg</a>\n'
#           '<div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/JMg3O1Ol.jpg?e=1723662980&amp;s=gD7DIww_ki1sPOy01Rviag"/></div>\n'
#           '\n'
#           '\n'
#           '四爺的三分能力還有在聯盟前五嗎？我是很懷疑...\n'
#           '\n'
#           '上季三分命中率前10的球員\n'
#           '<a href="http://i.imgur.com/tvaMyp3.jpg" rel="noreferrer noopener '
#           'nofollow" target="_blank">http://i.imgur.com/tvaMyp3.jpg</a>\n'
#           '<div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/tvaMyp3l.jpg?e=1723693558&amp;s=XIwoU0CHI73dqdi5q4wR4Q"/></div>\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 101.12.27.114 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723484443.A.12E.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723484443.A.12E.html</a>\n'
#           '</span><div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/8LHn3Jul.jpeg?e=1723726411&amp;s=xuktpcBMa_t_hab9izx_og"/></div>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723484443.A.12E.html',
#   'title': '[花邊] 2k25三分能力值Top5 Curry99最高'},
#  {'html': '\n'
#           '<a href="https://x.com/FabrizioRomano/status/1823033185921360062" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/FabrizioRomano/status/1823033185921360062</a>\n'
#           '<a href="https://i.imgur.com/WtLlXvl.jpg" rel="noreferrer noopener '
#           'nofollow" target="_blank">https://i.imgur.com/WtLlXvl.jpg</a>\n'
#           '<div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/WtLlXvll.jpg?e=1723724519&amp;s=R8tql4wAlLU3w1foX72qmA"/></div>\n'
#           'Fabrizio Romano\n'
#           '\n'
#           'Kevin Durant, about to become a new minority stakeholder at Paris\n'
#           'Saint-Germain!\n'
#           '\n'
#           'Decision made as\n'
#           '@Romain_Molina\n'
#           ' reported.\n'
#           '\n'
#           'KD成為PSG新任少數股東 就如同@Romain_Molina報導那樣\n'
#           '\n'
#           '心得:LBJ投資利物浦 KD投資PSG\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 118.166.204.2 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723485721.A.707.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723485721.A.707.html</a>\n'
#           '</span><span class="f2">※ 編輯: madeinheaven (118.166.204.2 臺灣), '
#           '08/13/2024 02:04:30\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723485721.A.707.html',
#   'title': '[花邊] KD成為PSG少數股東'},
#  {'html': '\n'
#           '<span class="f2">※ 引述《spdhkqfbjgy (小魯蛇)》之銘言：\n'
#           '</span><span class="f6">: 這次奧運Tatum完全是LBJ KD後的選擇 甚至被DNP\n'
#           '</span><span class="f6">: 很難想像這是當今NBA第一小前鋒\n'
#           '</span><span class="f6">: 連續三年年度第一隊的球星\n'
#           '</span><span class="f6">: 今年數據乍看之下差不多\n'
#           '</span><span class="f6">: JT   26.9分8.1籃板4.1助攻 第一隊\n'
#           '</span><span class="f6">: KD   27.1分6.6籃板5.0助攻 第二隊\n'
#           '</span><span class="f6">: LBJ 25.7分7.3籃板8.3助攻 第三隊\n'
#           '</span><span class="f6">: 既然能被連續三年選為第一隊\n'
#           '</span><span class="f6">: 代表JT已經逐漸超越這兩位了?\n'
#           '</span><span class="f6">: 但是奧運表現怎感覺兩位老人實力還是碾壓他?\n'
#           '</span><span class="f6">: 究竟是JT例行賽表現比LBJ KD好 大賽才軟手\n'
#           '</span><span class="f6">: 還是隊友五門齊 戰績太好才讓他年年第一隊 甚至奪冠 其實統治力普普\n'
#           '</span><span class="f6">: 所以現在NBA第一小前鋒到底是誰\n'
#           '</span><span class="f6">: 連續三年第一隊的JT\n'
#           '</span><span class="f6">: 還是生涯末年的LBJ或是KD\n'
#           '</span>主因是奧運可以蹲坑 陣地戰比例很高\n'
#           '季後賽也是 需要陣地戰的比例很高\n'
#           '有單兵破陣能力的 目前FIBA前三應該就阿肥LBJ跟無差別單打的KD\n'
#           '\n'
#           'JT抱歉 這個能力還沒有\n'
#           '\n'
#           '而NBA多數比賽是高pace 強調快速進攻\n'
#           '鋒線掃蕩防守\n'
#           '進攻效用遠大於防守的內容\n'
#           '不過原因是因為防守很難\n'
#           '但你有個能無限掃蕩 各個進攻都能去干擾的鋒線 價值就出來了\n'
#           '聯盟之後最主要的強角也多有這個能力，斑馬 字母哥 JT\n'
#           '然後以前有這個能力的LBJ和KD都老了\n'
#           '\n'
#           'LBJ和KD雖吃虧，慢慢沒有這個很重要的能力，但也受限進攻簡單，球商夠高、能力又維\n'
#           '持得好，所以效率能維持著較久一點 是相對得利之處。\n'
#           '\n'
#           '所以整體來說，JT現在價值和能比他們兩個表現的地方多很正常，但破陣和觀念這種提高\n'
#           '效率的技術，他還沒有，還是很多亂打就是下個要提升的地方了\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 1.164.57.153 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723492095.A.FF7.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723492095.A.FF7.html</a>\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723492095.A.FF7.html',
#   'title': 'Re: [討論] 現在的Tatum有比LBJ KD強嗎'},
#  {'html': '\n'
#           'JamesPO出跟KD、Curry在巴黎鐵塔的合照\n'
#           '\n'
#           '<a href="https://x.com/KingJames/status/1822751864561221842" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/KingJames/status/1822751864561221842</a>\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '詹杜柯看一次少一次~\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 122.121.191.179 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723507125.A.EAB.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723507125.A.EAB.html</a>\n'
#           '</span><div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/f8rIzQKl.jpeg?e=1723719284&amp;s=B79pJuU1Uzfwapn0Fm2TuA"/></div><div '
#           'class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/hlWVc6il.jpg?e=1723679111&amp;s=BG96vGxhLwLT35L79EAyuw"/></div><div '
#           'class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/86l2mjvl.jpeg?e=1723681512&amp;s=GH9FCYsudBgS3syhpQXWLw"/></div><div '
#           'class="richcontent"><img alt="" loading="lazy" '
#           'src="https://i4.disp.cc/imgur/CKws1xH.jpg"/></div>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723507125.A.EAB.html',
#   'title': '[花邊] 老詹昨日在推特PO出跟KD、Curry合照'},
#  {'html': '\n'
#           '<a href="https://x.com/utahjazz/status/1823028183450661325" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/utahjazz/status/1823028183450661325</a>\n'
#           '\n'
#           'We have signed center/forward Kyle Filipowski\n'
#           '\n'
#           '\n'
#           '<a href="https://x.com/MikeAScotto/status/1823152163201171751" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/MikeAScotto/status/1823152163201171751</a>\n'
#           '\n'
#           'The Utah Jazz signed rookie Kyle Filipowski to a four-year, $12 '
#           'million deal,\n'
#           'league sources told @hoopshype. The deal is fully guaranteed for '
#           'the first two\n'
#           'years, is non-guaranteed Year 3, and has a team option Year 4. The '
#           'former Duke\n'
#           'star was the 32nd pick of the 2024 NBA Draft\n'
#           '\n'
#           '\n'
#           '爵士隊在今天正式宣布簽下二輪新秀 Kyle Filipowski\n'
#           '\n'
#           '達成四年1200萬美金的合約\n'
#           '\n'
#           '其中前面兩年合約都是全額保障，第三年合約為非保障，第四年則是球隊選擇權\n'
#           '\n'
#           '\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 150.117.39.40 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723508655.A.354.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723508655.A.354.html</a>\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723508655.A.354.html',
#   'title': '[情報] Kyle Filipowski 跟爵士簽下4年1200萬合約'},
#  {'html': '\n'
#           '<a href="https://x.com/ClutchPoints/status/1823149049937264926" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/ClutchPoints/status/1823149049937264926</a>\n'
#           '@ClutchPoints\n'
#           'James Harden: "I got the pleasure &amp; opportunity to be with '
#           'Tyrese [Maxey] 2\n'
#           'years ago. He work his a*s off. What did you just sign for?"\n'
#           '\n'
#           'TM: "$204 million."\n'
#           '\n'
#           'JH: "Bank! Cherish it. Put the work in. The results will pay off '
#           'later."\n'
#           '\n'
#           '(via@ricohinesbball)\n'
#           '\n'
#           '登登:「兩年前我所幸有機會與Tyrese(Maxey)一起打球。他超努力練習。而你剛簽下多\n'
#           '少?」\n'
#           '\n'
#           'Tyrese Maxey:「2.04億鎂。」\n'
#           '\n'
#           '登登:「開銀行啊! 珍惜機會。努力練習。總是會開花結果。」\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 118.163.112.2 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723512452.A.E4B.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723512452.A.E4B.html</a>\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723512452.A.E4B.html',
#   'title': '[花邊] Harden在訓練營以Maxey大約激勵球員們'},
#  {'html': '\n'
#           '<a href="https://reurl.cc/pvx2Kl" rel="noreferrer noopener '
#           'nofollow" target="_blank">https://reurl.cc/pvx2Kl</a> Dan Wolken, '
#           'USA TODAY\n'
#           '\n'
#           'He came out in shoes as shiny and golden as the medal he would put '
#           'around his\n'
#           'neck Saturday night for the third, and perhaps final, time in his '
#           'career.\n'
#           '<span class="f3 hl">他穿著一雙閃閃發亮的金色球鞋出場，就像他週六晚上將掛在脖子上的金牌一樣耀眼\n'
#           '</span>\n'
#           'For LeBron James, the color choice seemed like a statement: About '
#           'his intent\n'
#           'in the Olympics, about his mission for Team USA, about everything '
#           'in his\n'
#           'basketball life leading to another gold medal.\n'
#           '<span class="f5 hl">對LeBron來說，這個顏色選擇似乎是個宣言：表達他在奧運場上的決心、對美國隊的使命\n'
#           '</span><span class="f5 hl">，以及他籃球生涯中一切努力的目標——另一枚金牌。</span>\n'
#           '\n'
#           'Even with all he’s done at age 39, James didn’t come here just to '
#           'help his\n'
#           'country win a tournament. He proved a point. As long as he’s '
#           'playing this\n'
#           'sport, nobody is going to shine brighter.\n'
#           '<span class="f3 hl">即使已經39歲，LeBron來這裡不僅僅是為了幫助國家贏得冠軍，他還想證明自己。\n'
#           '</span><span class="f3 hl">只要他還在打球，就沒有人能比他更耀眼\n'
#           '</span>\n'
#           'LeBron, in fact, has still got it. He was the best player at the '
#           'Olympics,\n'
#           "winning the tournament's MVP award. He’s still so clearly capable "
#           'of\n'
#           'dominating a basketball game at a level hardly anyone in the world '
#           'can match.\n'
#           '<span class="f5 hl">LeBron寶刀未老，他是奧運上最好的球員，並贏得MVP，依然主宰比賽，幾乎無人能抗衡\n'
#           '</span>\n'
#           'And it leads to one question more important than what he did over '
#           'this last\n'
#           'month: How are the Los Angeles Lakers screwing up this chapter of '
#           'his career\n'
#           'so badly?\n'
#           '<span class="f3 hl">這讓人不得不問一個問題，比LeBron這個月所做的一切還要重要：\n'
#           '</span><span class="f6 hl">洛杉磯湖人隊到底怎麼了？怎麼會把他的職業生涯搞得這麼糟糕？</span>\n'
#           '\n'
#           'I’ll admit, despite being named All-NBA third team, I thought it '
#           'finally\n'
#           'looked like James lost a step last season. And I thought because of '
#           'how much\n'
#           'investment they had tied up in James and Anthony Davis that it '
#           'didn’t really\n'
#           'matter what else they did: The Lakers were going to be stuck with '
#           'an old team\n'
#           'that would continue to be in play-in purgatory as James continued '
#           'declining\n'
#           'until his inevitable retirement.\n'
#           '<span class="f5 hl">我得承認，儘管LeBron被選入NBA第三隊，我認為上賽季他似乎終於開始下滑了。而且，\n'
#           '</span><span class="f5 hl">，由於他們在 LeBron和AD身上的巨額投資，我不認為他們還能做什麼：\n'
#           '</span><span class="f5 '
#           'hl">湖人將被困在一個老化的隊伍中，繼續在附加賽掙扎，直到LeBron不可避免的退休。\n'
#           '</span>\n'
#           'Maybe the Lakers thought so, too. Maybe that explains why Rob '
#           'Pelinka has sat\n'
#           'on his hands this offseason, failing to make a single roster move '
#           'to improve\n'
#           'a team that went 47-35 last season and finished seventh in the '
#           'Western\n'
#           'Conference.\n'
#           '<span class="f3 hl">或許湖人也是這麼想的。這或許可以解釋為什麼Pelinka在這個休賽期無所作為，\n'
#           '</span><span class="f3 hl">未能進行任何隊伍調整來改善一支上賽季取得47勝35負、西區第七的球隊。\n'
#           '</span>\n'
#           'But after watching James plow through everyone at the Olympics, I’m '
#           'actually\n'
#           'now enraged at the Lakers’ front office for fiddling around on the '
#           'fringes\n'
#           'the last few years while time runs short on this once-in-a-lifetime '
#           'career.\n'
#           '<span class="f6 hl">但在看LeBron在奧運上橫掃所有對手後，我現在對湖人的管理層感到憤怒，\n'
#           '</span><span class="f6 hl">他們在過去幾年裡一直在浪費時間，而LeBron這位千載難逢的黃金時期正在縮短。\n'
#           '</span>\n'
#           'OK, so he’s not quite the defender he once was, and you can’t play '
#           'him 82\n'
#           'games the way he used to. But those are the only concessions to '
#           'time James\n'
#           'has made as he has reached his late 30s.\n'
#           '<span class="f3 hl">他不再是以前的防守悍將，不能打滿82場，但這些30多歲後的他唯一需要讓步的地方\n'
#           '</span>\n'
#           'His physical capability is still elite. His passing is still '
#           'otherworldly.\n'
#           'His ability to read the game and make decisions may be better than '
#           'ever. When\n'
#           'he’s determined to just put his head down and be a freight train to '
#           'the rim,\n'
#           'nobody in the world can stop him.\n'
#           '<span class="f5 hl">他的身體能力仍然是頂級的。他的傳球仍然超凡脫俗。他閱讀比賽和做出決定的能力可能\n'
#           '</span><span class="f5 hl">比以往任何時候都好。當他決定低頭衝向籃筐時，世界上沒有人能阻止他。\n'
#           '</span>\n'
#           'Can James still lead a team to the NBA title? How could you watch '
#           'these\n'
#           'Olympics and think anything else?\n'
#           '<span class="f6 hl">LeBron還能帶領一支球隊奪得NBA冠軍嗎？看了這些奧運比賽後，你還會怎麼想呢？\n'
#           '</span>\n'
#           'Even on a team full of superstars, he elevated above everyone. When '
#           'it’s\n'
#           'America’s best versus the world’s best, there’s still no doubt who '
#           'gets\n'
#           'the job done.\n'
#           '<span class="f5 hl">即使在超巨的球隊中，他仍然高人一等。當美國最強vs世界最強 毫無疑問誰能完成任務\n'
#           '</span>\n'
#           'In this tournament, nobody else was going to do it.\n'
#           '<span class="f3 hl">在這場比賽，沒有人能做到</span>\n'
#           '\n'
#           'Anthony Edwards didn’t have the gravitas. Jayson Tatum was just '
#           'along for\n'
#           'the ride. The guys who are supposed to eventually replace James as '
#           'the\n'
#           'American face of the league weren’t ready for this.\n'
#           '<span class="f5 hl">AE還沒有足夠的影響力。JT只是隨波逐流。那些被看好能取代 LeBron成為美國籃壇新面孔\n'
#           '</span><span class="f5 hl">，還沒有準備好迎接這個挑戰。</span>\n'
#           '\n'
#           'In the end, this team was conceived by and for James to have one '
#           'last Olympic\n'
#           'run, with his few true peers in the NBA pantheon alongside.\n'
#           '<span class="f3 hl">最終，這支球隊是為LBJ打造的，讓他最後1次征戰奧運，與NBA少數的真正同儕並肩作戰\n'
#           '</span>\n'
#           'But from training camp to exhibitions and all the way to the final '
#           'game,\n'
#           'everyone else on this team rode the roller coaster. Steph Curry '
#           'went from\n'
#           'being uncomfortable early to making a barrage of 3-pointers that '
#           'held off\n'
#           'France in the gold medal game. Kevin Durant had to work his way '
#           'back from\n'
#           'injury. Joel Embiid was useful in some moments, out of place in '
#           'others.\n'
#           '<span class="f6 hl">但從訓練營到熱身賽，一直到最後一場比賽，這支球隊的其他人都經歷了起伏。\n'
#           '</span><span class="f6 hl">Curry一開始有些不適，但後來連續投進三分球，幫助美國隊在金牌戰中擊敗法國。\n'
#           '</span><span class="f6 '
#           'hl">KD必須從傷病中恢復過來。Embidd在某些情況有用，但在其他時間則顯得格格不入。\n'
#           '</span>\n'
#           'James, though, was always there. He erased potential humiliating '
#           'moments\n'
#           'against South Sudan and Germany. He was the Americans’ energy '
#           'source in the\n'
#           'preliminary rounds. When everything was on the line against Serbia, '
#           'James\n'
#           'willed Team USA across the finish line. And in the gold medal game '
#           'against\n'
#           'France, everything ran through him: 14 points, six rebounds, 10 '
#           'assists in\n'
#           'nearly 33 minutes on the floor.\n'
#           '<span class="f5 hl">然而，LeBron一直都在。他化解了對南蘇丹和德國的潛在羞辱時刻。他是美國隊預賽階段\n'
#           '</span><span class="f5 hl">的能量來源。當一切攤在賽場上vs塞爾維亞時，LeBron帶領美國隊衝過終點線。\n'
#           '</span><span class="f5 '
#           'hl">在金牌戰vs法國時，一切都由他來主導：33分鐘內得到14分、6個籃板和10次助攻\n'
#           '</span>\n'
#           'Even on a team full of superstars, this gold medal was only '
#           'possible because\n'
#           'James wore red, white and blue one more time. Nearing his 40th '
#           'birthday, we’\n'
#           've never seen anything like it.\n'
#           '<span class="f3 hl">即使在一支全明星球隊中，這枚金牌只有在 LeBron再次穿上紅、白、藍球衣的情況下才有\n'
#           '</span><span class="f3 hl">可能獲得。在他接近40歲生日之際，我們從未見過這樣的景象。\n'
#           '</span>\n'
#           'And what are the Lakers doing with this national treasure? Selling '
#           'tickets\n'
#           'and running out the clock.\n'
#           '<span class="f6 hl">而湖人隊正在用這個國寶做什麼？賣票和虛度光陰。\n'
#           '</span>\n'
#           'There probably aren’t many more great years left, but these '
#           'Olympics showed\n'
#           'that it’s still worth it for the Lakers to make the most of them – '
#           'trading\n'
#           'draft picks, mortgaging the future, whatever it takes.\n'
#           '<span class="f5 hl">LeBron可能沒有太多黃金賽季了，但這次奧運表面，湖人還是值得為他全力以赴——\n'
#           '</span><span class="f5 hl">交易選秀權、抵押未來，不惜一切代價。\n'
#           '</span>\n'
#           'He’s still one of the best players on the planet, and there’s no '
#           'time to\n'
#           'waste. What are they waiting for?\n'
#           '<span class="f3 hl">他仍然是世界上最好的球員之一，沒有時間可以浪費。湖人隊還在等什麼？\n'
#           '</span>\n'
#           'James will be 43 years old when the next Summer Olympics come to '
#           'Los Angeles,\n'
#           'and it’s impossible to believe he’ll still be this kind of player '
#           'four\n'
#           'years from now. But with LeBron James, you don’t just have to allow '
#           'for the\n'
#           'impossible. You have to imagine it.\n'
#           '<span class="f6 hl">下一次夏季奧運在洛杉磯舉行時，LeBron將43歲，很難相信四年後他還能保持這樣的實力\n'
#           '</span><span class="f6 hl">但是對於LeBron '
#           'James，你不僅要考慮不可能的事，還要想像它。</span>\n'
#           '\n'
#           'Team USA did and was rewarded with a gold medal. Now it’s the '
#           "Lakers' turn.\n"
#           '<span class="f5 hl">美國隊做到了，並因此獲得了金牌。現在輪到湖人隊了。\n'
#           '</span>\n'
#           '\n'
#           '備註\n'
#           '<a href="https://i.imgur.com/Xu527or.png" rel="noreferrer noopener '
#           'nofollow" target="_blank">https://i.imgur.com/Xu527or.png</a>\n'
#           '<div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/Xu527orl.png?e=1723721624&amp;s=N9dUOTt2Eaog8CQjGLns0w"/></div>奧運沒有薪資上限\n'
#           '\n'
#           '<a href="https://i.imgur.com/xSZOgOb.jpg" rel="noreferrer noopener '
#           'nofollow" target="_blank">https://i.imgur.com/xSZOgOb.jpg</a>\n'
#           '<div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/xSZOgObl.jpg?e=1723698278&amp;s=238Xxizi6wbNQ_aZXhbgNw"/></div>\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 220.129.198.181 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723518709.A.E3C.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723518709.A.E3C.html</a>\n'
#           '</span><span class="f2">※ 編輯: usnavyseal (220.129.198.181 臺灣), '
#           '08/13/2024 11:12:34\n'
#           '</span>感謝\n'
#           '<span class="f2">※ 編輯: usnavyseal (220.129.198.181 臺灣), 08/13/2024 '
#           '11:22:21\n'
#           '</span><div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/Avn5oEDl.jpeg?e=1723685903&amp;s=Y4iUBJWc9MJWIlTtEHnCWQ"/></div>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723518709.A.E3C.html',
#   'title': '[外絮] 奧運最佳球員LBJ 但湖人未珍惜他的才華'},
#  {'html': '\n'
#           '<a '
#           'href="https://x.com/clutchpoints/status/1823199565484318987?s=46" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/clutchpoints/status/1823199565484318987?s=46</a>\n'
#           '\n'
#           'Kevin Durant and Devin Booker having fun after winning the gold '
#           'medal\n'
#           '\n'
#           'KD和Booker在贏得金牌後玩得很開心\n'
#           '\n'
#           '<a href="https://i.imgur.com/ckGEPLd.jpeg" rel="noreferrer noopener '
#           'nofollow" target="_blank">https://i.imgur.com/ckGEPLd.jpeg</a>\n'
#           '<div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/ckGEPLdl.jpeg?e=1723718831&amp;s=1oMoXPPqgeZuTy9IRyUw1A"/></div><a '
#           'href="https://i.imgur.com/8nD3dlr.jpeg" rel="noreferrer noopener '
#           'nofollow" target="_blank">https://i.imgur.com/8nD3dlr.jpeg</a>\n'
#           '<div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/8nD3dlrl.jpeg?e=1723670016&amp;s=DlUXtx_j7YHK-kiCsT6Hhg"/></div>\n'
#           '-\n'
#           'KD：好開心喔～\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 223.137.199.231 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723520348.A.742.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723520348.A.742.html</a>\n'
#           '</span><div class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/7PyEzHRl.jpg?e=1723683371&amp;s=EBbwn3uN2E4oZ82R6vO2VQ"/></div><div '
#           'class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/7eeNnhDl.jpg?e=1723713227&amp;s=hrhSAWT_5zbSo-SIqFGIag"/></div><div '
#           'class="richcontent"><img alt="" loading="lazy" '
#           'src="https://cache.ptt.cc/c/https/i.imgur.com/s1MR0cbl.jpeg?e=1723666805&amp;s=My_XHHPTXpGWNNF6i6q86Q"/></div>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723520348.A.742.html',
#   'title': '[花邊] KD和Booker在泳池戲水'},
#  {'html': '\n'
#           '<a href="https://x.com/ClutchPoints/status/1823212124853744112" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/ClutchPoints/status/1823212124853744112</a>\n'
#           '@ClutchPoints\n'
#           '“Would you trade your three Olympic gold medals for one NBA ring?”\n'
#           '\n'
#           'Carmelo Anthony: “No... A medal means something totally different '
#           'than an\n'
#           'NBA championship… It’s the passion. It’s the pride...  For a whole '
#           'country.\n'
#           '”\n'
#           '\n'
#           '(via@BasketNews_com)\n'
#           '\n'
#           '記者:「你願意用三面奧運金牌換1個NBA戒指嗎?」\n'
#           '\n'
#           '瓜哥:「不要...一面金牌的意義完全跟NBA冠軍不同...這是熱情。這是驕傲...對於整個國家而言。」\n'
#           '\n'
#           '\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 118.163.112.2 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723526362.A.7F7.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723526362.A.7F7.html</a>\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723526362.A.7F7.html',
#   'title': '[情報] 記者問瓜:3奧運金牌換NBA冠? 瓜:不要'},
#  {'html': '\n'
#           '來源\n'
#           '\n'
#           '<a '
#           'href="https://x.com/FIBA/status/1822921708782690524?t=eqh7bdfNzeD8NKYkjDI5qQ&amp;s=19" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://x.com/FIBA/status/1822921708782690524?t=eqh7bdfNzeD8NKYkjDI5qQ&amp;s=19</a>\n'
#           '\n'
#           'LeBron the new Olympic steals king and other all-time top 10 movers '
#           'and shakers\n'
#           '\n'
#           'LeBron James had a magical 2024 Olympics, winning the gold medal '
#           'while also jump\n'
#           'ing to No. 1 as the all-time steals king.\n'
#           '\n'
#           '詹姆斯成為奧運男籃歷史第一的抄截王\n'
#           '\n'
#           '以下前八排名\n'
#           '\n'
#           '1.LeBron James        USA           44\n'
#           '\n'
#           '2.Andrei Kirilenko      Russia       43\n'
#           '\n'
#           '3.Patty Mills               Australia   40\n'
#           '\n'
#           '4.Rudy Fernandez     Spain          38\n'
#           '\n'
#           '4.Chris Paul                USA           38\n'
#           '\n'
#           '6.Manu Ginobili          Argentina  37\n'
#           '\n'
#           '7.Dwyane Wade         USA            35\n'
#           '\n'
#           '8.Kevin Durant            USA          33\n'
#           '\n'
#           '\n'
#           '同場加映\n'
#           '\n'
#           'LBJ以139次助攻排名奧運歷史第二\n'
#           '\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 223.137.86.32 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723527187.A.57F.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723527187.A.57F.html</a>\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723527187.A.57F.html',
#   'title': '[花邊] LBJ成為奧運歷史第一抄截王！'},
#  {'html': '\n'
#           'Podcast P with Paul George:\n'
#           '<a href="https://youtu.be/CYbcORZ1EQA?t=474" rel="noreferrer '
#           'noopener nofollow" '
#           'target="_blank">https://youtu.be/CYbcORZ1EQA?t=474</a>\n'
#           '<div class="richcontent"><div class="resize-container"><div '
#           'class="resize-content"><iframe allowfullscreen="" '
#           'class="youtube-player" frameborder="0" '
#           'src="//www.youtube.com/embed/CYbcORZ1EQA" '
#           'type="text/html"></iframe></div></div></div>\n'
#           'Trae Young談Dejounte Murray\n'
#           '\n'
#           'Young: 說實話有好有壞。唯一的壞處是沒能如我們想要的那樣，多贏一些比賽。好的部\n'
#           '分是我們建立了一段長久的關係。我們的關係超越了籃球，我們都是重視家庭的人，我們\n'
#           '的道德觀非常相似，無論是在我們身邊的人，還是在我們日常生活中所做的事情上。我們\n'
#           '總是試圖為別人付出等等，這就是為什麼我們的關係是一輩子的。\n'
#           '\n'
#           '但場上就有點困難，我們都想贏。但我們不是第一組無法成功合作的搭檔，我們也不會是\n'
#           '最後一組，畢竟你有兩個控球後衛在場。當時(交易Dejounte Murray)我非常興奮，在新\n'
#           '聞公布之前，我就是第一個打電話給他的人。我非常興奮，因為我知道我有一個人可以來\n'
#           '幫助我，我知道他是一個非常好的球員，但在球場上兩人合作表現未達預期，這感覺糟透\n'
#           '了，我們兩個都承認這點，但這就是比賽的一部分。如果這行不通，球隊就必須想辦法做\n'
#           '出下一步的動作和決策。\n'
#           '\n'
#           'PG問: 當他剛來的時候，當時你有沒有感覺，很喜歡這組合，他能控球，減輕我的壓力，\n'
#           '有時候我也可以當定點射手。\n'
#           '\n'
#           'Young: 是的，我認為這很難，因為我們兩個都很無私。合作初期有些時候，我只是把球\n'
#           '傳給他，而他也想要變得積極進攻，但他也是控球後衛，他也不是想著得分優先的人。\n'
#           '\n'
#           '但當我在場上的時候，有時他會得分後衛，而這種組合搭配就是行不通。很多時候從理論\n'
#           '上來看，你可能會覺得這種組合應該有效，因為在聖安東尼奧，他是一個非常好的防守者\n'
#           '，以防守為名，而不是得分手，他可以做所有事情，籃板、得分、讓其他人參與進攻。但\n'
#           '當他來到我們這裡的時候，那種感覺就是不一樣，所以事情沒能如願，真的很可惜。\n'
#           '\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 220.141.207.170 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1723529805.A.5EC.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1723529805.A.5EC.html</a>\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1723529805.A.5EC.html',
#   'title': '[花邊] Trae Young談Dejounte Murray'},
#  {'html': '\n'
#           '<span class="hl">主旨</span>\n'
#           '\n'
#           'I  . NBA 板作為 NBA 群組之綜合性看板，歡迎<span class="hl">『具有想法且經整理過後並以之</span>\n'
#           '<span class="hl">     與所有看板板友分享與討論為主要宗旨之內容』</span>之使用為最主要目的。\n'
#           '\n'
#           'II . 板友參與討論時，<span class="f3 hl">具有維護看板基本秩序與品質的責任與義務</span>，並且不應\n'
#           '     主動挑起任何無意義爭端，使看板保有其最初看板討論功能。\n'
#           '\n'
#           'III. 看板板友在發表文章或使用推文系統時，必須確保其符合 NBA 板板旨，並\n'
#           '     力求<span class="f3 hl">「內容與資訊之正確性」</span>\n'
#           '\n'
#           'IV . 板主以<span class="hl">「維護看板基本討論品質與秩序」</span>以及<span '
#           'class="hl">「協助看板內容維持水準」</span>\n'
#           '     為其最高指導原則，如有濫用板面或蓄意破壞秩序者，得以使用看板管理\n'
#           '     工具為手段控制之(如刪文/劣退/水桶/鎖文等)\n'
#           '\n'
#           'V  . 本板<span class="f3 hl">以 NBA 之競技主體</span>為討論範圍，其他內容請盡量專板專用。\n'
#           '     e.g. 影片→NBA_Film，閒聊→NBAEasyChat.....\n'
#           '\n'
#           'VI . NBA_Picket為本板之延伸公務看板, 兩板處分及發言權利連動, 此規定溯及既往.\n'
#           '\n'
#           '                           <span class="hl"> 內容管理</span>\n'
#           '<span class="f2">※1.發文格式※</span>\n'
#           '<span class="f5 hl">1.</span>Live：轉播文，<span class="f3 '
#           'hl">每場比賽一篇為限</span>，須列出雙方先發名單或上場球員名單(英文名)。\n'
#           '\n'
#           '         1.以賽前半小時為準，先發者先贏。\n'
#           '     \u3000\u30002.重複者情於須於<span class="f3 '
#           'hl">10分鐘內刪除，違者逕行刪文處理。</span>\n'
#           ' \u3000\u3000\u3000\u30003.<span class="f1 '
#           'hl">禁止將轉播網站之連結修改營利。</span>請放上原本轉播的連結，違者板主可視\n'
#           '           情況處分。\n'
#           '         <span class="f6 '
#           'hl">4.網址經他人檢舉證實為挖礦、病毒網址者，以鬧板論，板主應加重處置。</span>\n'
#           '<span class="f6 hl"> </span>5.發文、推文張貼非法轉播連結者，板主應加以刪除並得視情節禁言處分。\n'
#           '         6.發文、推文徵求非法轉播連結者，板主應加以刪除並得視情節禁言處分。\n'
#           '\n'
#           '\n'
#           '  <span class="f5 hl">2.</span>Box：賽後數據，<span class="f3 '
#           'hl">每場比賽以一篇為限</span>，板主得視情況決定留精美者或先發者\n'
#           '\n'
#           '         1.過往之戰績、數據、BOX、更改標題為<span class="f3 '
#           'hl">[舊聞]，一日板面總數限定兩篇</span>\n'
#           '           違者刪除。\n'
#           '         2.BOX、Live兩分類不計入單日發文總數，但若發其他分類文章，則計入\n'
#           '   \u3000     （例如BOX發五篇，再發一篇討論則屬超貼，再發一篇LIVE則不算。）\n'
#           '\n'
#           '  <span class="f5 hl">3.</span>外絮：外電翻譯，發文者最少必須說明或翻譯文章內容大綱。\n'
#           '\n'
#           '         1.自我翻譯字數須滿足１５０字。<span class="f1 hl">需附上完整連結否則逕行刪除</span>。\n'
#           '         2.譯文須符合原文，不得添加無關字詞，外絮以雜誌、地方報專欄的文章適用\n'
#           '           須經基礎查證。\n'
#           '         3.<span class="f3 hl">字數未足150字，請使用[情報]。</span>\n'
#           '\u3000\u3000 \u3000\u30004.此分類須加註相關心得，個人意見可附於其中。\n'
#           '\n'
#           '  <span class="f5 hl">4.</span>專欄：由媒體專欄、運動網站、運動部落格文章，須滿足１５０字。\n'
#           '\n'
#           ' \u3000\u3000\u3000\u30001.轉貼者須附上作者名，原文網址連結以及出處．<span class="f3 '
#           'hl">每人每天限發一篇專欄。</span>\n'
#           '<span class="f3 hl">(一篇限制包含文章自刪、被刪、轉文)</span>\n'
#           '<span class="f3 hl"> </span>2.若為翻譯專欄，請盡量附上原文連結，供板友對照。\n'
#           '         3.<span class="f3 hl">標題及內文</span><span class="f1 '
#           'hl">球員姓名請一律使用英文姓名</span>，<span class="f1 hl">球隊名使用台灣譯名</span>\n'
#           '          （若標題中譯名符合台灣通用譯名可不修改，由板主群判定。）\n'
#           '\n'
#           '  <span class="f5 hl">5.</span>情報：有關NBA新聞、每日戰績、電視轉播表、自行整理的NBA相關訊息。\n'
#           '\n'
#           '         1.<span class="f3 '
#           'hl">每人每天限發一篇情報</span>，內容雷同者原則上只留一篇，以第一篇發表\n'
#           '           時間為準，此分類須加註相關心得。\n'
#           '           <span class="f3 hl"> (一篇限制包含文章自刪、被刪、轉文)</span>\n'
#           '<span class="f3 hl"> </span>2.相關訊息須附完整來源網址，違者刪除。內容為翻譯新聞、引用外電新聞\n'
#           '           等，請盡量附上原文連結，供板友對照。照片不能當消息來源，請注意。\n'
#           '         3.新聞<span class="f3 hl">標題及內文</span><span class="f1 '
#           'hl">球員姓名請一律使用英文姓名</span>，<span class="f1 hl">球隊名使用台灣譯名</span>\n'
#           '          （若標題中譯名符合台灣通用譯名可不修改，由板主群判定。）\n'
#           '         4.今日賽況總整理之文章，一日版面總數限兩篇，不計入單日發文總數。\n'
#           '         5.本分類中國情報只開放正確度高的虎撲新聞\n'
#           '         6.即使網址為台灣，內容提供來源為對岸且非虎撲新聞區之情報仍在禁止之列。\n'
#           '         7.此分類不得用來偷渡無作者之新聞，而無作者定義由板規1-6-1定義。\n'
#           '         8.每日數據文來源需有列出該球員當天表現的特殊事蹟、里程碑或紀錄。\n'
#           '           <span class="f1 hl">(該場最高、今天最高...等等不在此列。)</span>\n'
#           '         9.為促進分流，台灣新聞不能作為此分類來源，請使用新聞分類\n'
#           '\n'
#           '  <span class="f5 hl">6.</span>新聞：台灣新聞（於台灣具實體媒體，電視台、報紙等）\n'
#           '\n'
#           '         1.文章內需附上文章作者與文章連結，<span class="f3 hl">每人每天限發一篇新聞。</span>\n'
#           '<span class="f1 hl">（文章作者需為真實姓名、筆名，體育中心不算文章作者。）</span>\n'
#           '<span class="f3 hl">(一篇限制包含文章自刪、被刪、轉文)</span>\n'
#           '<span class="f3 hl"> </span>2.內容雷同新聞原則上只留一篇，以第一篇發表時間為準。\n'
#           '         3.須注意新聞之即時性與即期性，非當天新聞原則上禁止轉貼，但若為板上\n'
#           '           尚無之消息，則可轉貼，須加註相關心得。\n'
#           '\u3000\u3000   \u30004.<span class="f3 '
#           'hl">禁止「快訊」形式新聞，非台灣新聞者請使用情報分類。</span>\n'
#           '         5.不具名新聞經查證出現標題殺人、造神、悖離原意等情事，將被刪除。\n'
#           '\n'
#           '  <span class="f5 hl">7.</span>討論：發表對NBA相關議題的各項討論\n'
#           '\n'
#           '         1.須遵守既有板規。\n'
#           '         2.字數以150字以上為原則。\n'
#           '         3.每人每天限發一篇討論。\u3000\u3000\u3000 \u3000\u3000\n'
#           '<span class="f3 hl">           (一篇限制包含文章自刪、被刪、轉文)</span>\n'
#           '         4.<span class="f1 '
#           'hl">依此分類偷渡其他分類規定下違規之文章，板主得加重水桶並刪除文章。</span>\n'
#           '<span class="f5 hl">8.</span>花邊：較無關NBA的比賽賽事、但新聞內主角都是NBA的主角人物或相關情事，\n'
#           '          則選用此分類。例如：退役球員健康狀況、球員夜生活夜店、NBA公益\n'
#           '          活動、穿著造型流行、私下聚會等均可適用。\n'
#           '\n'
#           '         1.<span class="f1 hl">每日每人能貼一篇[花邊]。</span><span class="f3 '
#           'hl">(一篇限制包含文章自刪、被刪、轉文)</span>\n'
#           '         2.來源若為新聞/文章/專欄，<span class="f1 '
#           'hl">則必須有記者或作者名，</span>違者刪文板規處\n'
#           '           理。\n'
#           '         3.來源若為推特/IG/臉書：\n'
#           '          1) 來源須為球員，球團，記者，媒體等，<span class="f1 '
#           'hl">不開放其他個人社群媒體。</span>\n'
#           '             板主得視來源可靠性裁定是否保留該文。\n'
#           '          2) <span class="f1 '
#           'hl">必須附上內容說明，中英皆可，不可只附上網址</span>，違者刪文板規處\n'
#           '             理。<span class="f3 hl">此類來源放寬150字限制。</span>\n'
#           '          3) 來源需附上完整網址，否則刪除板規處分。\n'
#           '         4.來源若為Youtube/Streamable:\n'
#           '          1) 開放類似賽後訪問，如球員及教練訪問。\n'
#           '          2) 不開放球員或球隊單場精華，集錦等影片。違者刪文板規處理。\n'
#           '          3) 不開放Youtuber或個人經營頻道影片。違者刪文板規處理。\n'
#           '          4) <span class="f3 hl">放寬150字限制。</span>\n'
#           '          5) <span class="f1 '
#           'hl">若發現為盜版連結或廣告嫌疑，板主應加以刪除並視情節劣退。</span>\n'
#           '         5.為促進分流，台灣新聞不能作為此分類來源，請使用新聞分類\n'
#           '\n'
#           '  <span class="f5 hl">9.</span>回文：回文部分視為<span '
#           'class="hl">不分類綜合討論</span>, 不受討論文單篇限制.\n'
#           ' \u3000\u3000\u3000   需遵守<span class="f3 hl">150字規範</span>及<span '
#           'class="f3 hl">單日上限五篇限制</span>.\n'
#           '\u3000\u3000\u3000\u3000\u3000情報與花邊之回文, 如附上連結以及提供相應主題之資訊.\n'
#           '   \u3000\u3000\u3000 視同情報與花邊, 得不受分類150字限制但是既然認定為情報與花邊\n'
#           '          就會占用情報與花邊額度.\n'
#           '\n'
#           ' <span class="f5 hl">10.</span>推圖：推圖視為推文的一部分, 其文字與圖像內容受本板發言規範.\n'
#           '          限制第二性徵裸露及粗言穢語, 每人每篇文章至多一圖, 超貼者視同\n'
#           '          發文規範違規.(推圖是指藉由推文構成的圖像,而非圖片)\n'
#           '\n'
#           '\n'
#           '其它規範：1.<span class="f3 hl">「亦伸文」「黃邱倫文」「黃及人文」「張曜麟文」「動網文」</span>\n'
#           '<span class="f3 hl">「basketball top 5文」「Haters文、籃球圈文」「鄭廷瑋文」</span>\n'
#           '<span class="f3 hl">「梁偉銘文」「陳雍仁文」「廖柏璋文」「吳政紘文」「鍾東穎文」</span>\n'
#           '<span class="f3 hl">「黎建忠文」AS文」</span>\n'
#           '<span class="f3 hl"> 「Skip文」「Amico文」「Koha by Monet文」</span>\n'
#           '\n'
#           '            以上新聞記者與網站之撰文或經板友投票或連續違犯本板合理新\n'
#           '            聞認定規定，<span class="f1 hl">禁止發布，違者刪除</span>。\n'
#           '\n'
#           '          2.<span class="f3 hl">「移花接木、翻譯錯誤記者文」</span>\n'
#           '           1)如經查證、檢舉記者出的新聞有錯誤資訊，就醜一\n'
#           '           2)<span class="f3 hl">醜一後</span>，公告記者姓名。\n'
#           '             往後<span class="f3 hl">貼此位記者新聞，標題打上記者姓名</span>。 \u3000\n'
#           '           3)<span class="f1 hl">再次被抓到</span>資訊嚴重錯誤，就立即<span '
#           'class="f1 hl">禁止此位記者的發文</span>。\n'
#           '\n'
#           '          3.承上，<span class="f3 '
#           'hl">「張志宇文」「大濕兄聊NBA」「盧品青文」「林暐立文」</span>\n'
#           '<span class="f3 hl">「陳元廷文」「Steam文」「唐嘉佑文」「邱晟軒文」「黃翊婷文」</span>\n'
#           '<span class="f3 hl">「巫旻璇文」「黃嘉彣文」「陳國偉文」「張良瑜文」 「陳品翔文」\n'
#           '</span><span class="f3 hl">            「陳冠宇文」「Legion '
#           'Hoops文」「廖志軒文」</span>違反本板新聞專欄相\n'
#           '             關規定醜一。\n'
#           '\n'
#           '            新聞記者張志宇相關新聞即起需要在標題註明 CCY 違者刪除.\n'
#           '            新聞記者盧品青相關新聞即起需要在標題註明 LPC 違者刪除.\n'
#           '            新聞記者林瑋立相關新聞即起需要在標題註明 LWL 違者刪除.\n'
#           '            新聞記者陳元廷相關新聞即起需要在標題註明 CYT 違者刪除.\n'
#           '            新聞記者Steam相關新聞即起需要在標題註明 STE 違者刪除.\n'
#           '            新聞記者唐嘉佑相關新聞即起需要在標題註明 TJY 違者刪除.\n'
#           '            新聞記者邱晟軒相關新聞即起需要在標題註明 CCS 違者刪除.\n'
#           '            新聞記者陳國偉相關新聞即起需要在標題註明 CGW 違者刪除.\n'
#           '            新聞記者林保宏相關新聞即起需要在標題註明 LBH 違者刪除.\n'
#           '            新聞記者黃翊婷相關新聞即起需要在標題註明 HYT 違者刪除.\n'
#           '            新聞記者巫旻璇相關新聞即起需要在標題註明 WMX 違者刪除.\n'
#           '            新聞記者黃嘉彣相關新聞即起需要在標題註明 HJW 違者刪除.\n'
#           '            新聞記者張良瑜相關新聞即起需要在標題註明 CLY 違者刪除.\n'
#           '            新聞記者陳品翔相關新聞即起需要在標題註明 CPX 違者刪除.\n'
#           '            新聞記者陳冠宇相關新聞即起需要在標題註明 CGY 違者刪除.\n'
#           '            新聞記者Legion Hoops相關新聞即起需要在標題註明 LH 違者刪除.\n'
#           '            新聞記者LakeShowYo相關新聞即起需要在標題註明 LSY 違者刪除.\n'
#           '            新聞記者曾思儒相關新聞即起需要在標題註明 ZSR 違者刪除.\n'
#           '            新聞記者廖志軒相關新聞即起需要在標題註明 LZX 違者刪除.\n'
#           '\n'
#           '          4.<span class="f3 hl">「中國文章或香港文章」</span>\n'
#           '           1)不論是使用外絮以外何種分類，\n'
#           '           2)<span class="f1 hl">標題及文中的球員名稱請</span><span class="f3 '
#           'hl">一律使用英文姓名</span><span class="f1 hl">，球隊名稱使用台灣譯名</span>\n'
#           '           3)禁止在非台灣通用譯名後方，括弧加註英文名的發文方式。\n'
#           '           4)若標題中譯名符合台灣通用譯名可不修改，由板主群判定。\n'
#           '\n'
#           '\n'
#           '            舉例：米高佐敦譯名\n'
#           '            修改=&gt;Michael Jordan             (O)\n'
#           '                =&gt;米高佐敦(Michael Jordan)   (X)\n'
#           '\n'
#           '\n'
#           '          5.<span class="f3 hl">「祭品文」</span>\n'
#           '\n'
#           '\u3000\u3000\u3000\u3000     請使用分類<span class="f1 '
#           'hl">[祭品]、[發錢]</span>。\n'
#           '       \u3000\u30001)<span class="f1 '
#           'hl">一人一日限定一篇，並須於一個禮拜內兌現</span>，<span class="f1 '
#           'hl">發送至少</span>10<span class="f1 hl">位板友以上，</span>\n'
#           '           2)若贈與內容過少，內容違反既有發文規則，板主視情節刪除或水桶劣退\n'
#           '           3)發錢文最少需發送10位板友以上 最低100p\n'
#           '             若未滿10位 則每位金額最低1000p\n'
#           '           4)非[祭品]、[發錢] 分類之文章亦可發錢，內容管理受該分類規定限制\n'
#           '\u3000\u3000\u3000\u3000\u3000\u3000 金額受以上第3點限制，並且如無違規推文亦會被歸零。\n'
#           '\n'
#           '\n'
#           '          6.<span class="f3 '
#           'hl">「問卷文」</span>\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\n'
#           '\n'
#           '         \u3000\u3000問卷無私營利性質者（無商業性質）可另開分類[問卷]，亦得遵守以下規範\n'
#           '\n'
#           '     \u3000\u3000\u30001)請先至NBA_Picket提申請。\n'
#           '           2)申請通過後，標題需以[問卷]作為分類。\n'
#           ' \u3000\u3000\u3000    3)一週內限一篇，所有板友共享此權利。\n'
#           ' \u3000\u3000\u3000    4)必須和ＮＢＡ或籃球、體育運動相關。\n'
#           ' \u3000\u3000\u3000    5)必須給予填答者Ｐ幣回饋。\n'
#           ' \u3000\u3000\u3000    6)勿請板主代為ＰＯ文。\u3000\n'
#           '\n'
#           '\u3000\u3000\u3000\u3000\u3000\u3000\n'
#           '      \u3000\u30007.<span class="f3 hl">「轉錄相關」</span>\n'
#           '\u3000\n'
#           '           \u3000轉錄之文章，應與本板主題相關，轉錄文章數視為一日發文配額\n'
#           '             <span class="f1 hl">請勿轉新聞。</span>\n'
#           '\n'
#           '\n'
#           '          8.<span class="f3 hl">「影片分享相關規定」</span>\n'
#           '\n'
#           '           1) 相關影片分享\n'
#           '              BOX文底下，請分享NBA官網連結，勿連結私人部落格其餘部分請洽\n'
#           '              影片版討論。\n'
#           '           2) 影片分享部落格\n'
#           '              只能放在簽名檔，其他如推文或是文章內文有分享之影片連結，\n'
#           '              皆以官網為主，以影片解說戰術之文章不再此限。\n'
#           '\n'
#           '\n'
#           '<span class="f2">※2.文章砍除原則※</span>\n'
#           '\n'
#           '  2-1. 因發文規則： 包含分身,自刪,轉文,被板主砍文，1人1日 發文總數限制5篇\n'
#           '   \u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 '
#           '情報、新聞未附連結、除情報與非水管花邊分類外未滿150字\n'
#           '                    、討論串已S、標題格式錯誤、無關NBA文、簡體字過多。\n'
#           '                  （簽名檔、標點符號、網址、數字不算字數，人名算一字、英文一個\n'
#           '                    單字算一字。非各國語言現有單字不算字數，例：RRRRRR。\n'
#           '                    如遇特殊情況，板主可判斷是否給予免罰，例如：大量數據文。\n'
#           '                    其餘有規定字數之板規皆依此標準判定，不再另外補述。）\n'
#           '  2-2. 個板閒聊文： 討論內容不足、無數據參考、無根據之閒聊文、心得薄弱等。\n'
#           '  2-3. 偏頗比較文： 球員比較主體悉為主觀臆測, 證據薄弱, 以偏概全者。\n'
#           '  2-4. 如果如果文： 加入過多假設性、不可能發生、如果成分高、臆測幻想文者。\n'
#           '  2-5. 自創爭點文： 自創詭異爭點對任意球星進行貶抑性比較者.\n'
#           '  2-6. 蓄意爭吵文： 發文攻訐, 模糊焦點, 證據薄弱, 以偏概全者。\n'
#           '  2-7. 重複新聞文： 包含情報、台灣媒體、陸文(虎撲)等等出處，但內容雷同者。\n'
#           '  2-8. 扭曲台媒文： 新聞或專欄過度腦補、扭曲事實、<span class="f6 '
#           'hl">農場標題</span>、或搧風點火者。\n'
#           '  2-9. 引戰反串文： 經舉報有抓到反串事證、語帶分化兩派球迷激化爭執者。\n'
#           '  2-10.沒梗系列文： 系列文討論到後來已經沒梗還回文，後幾篇的討論性不足者。\n'
#           '  2-11.仿標題系列： 仿同一頁面標題發文，想引起系列文鬧板者，板主得以退文。\n'
#           '  2-12.跟風他板文： 由他板開始引發的系列文，如刻意在板上發文模仿視同鬧板。\n'
#           '\n'
#           '\n'
#           '                             <span class="hl">治安管理</span>\n'
#           '<span class="hl"> 原則</span>\n'
#           '\n'
#           '\n'
#           '\n'
#           'I   . 本板治安管理以原則為主判例為輔板規為底線, 板政以治安為第一考慮.\n'
#           '\n'
#           'II  . 基於減少使用者對板規的忌憚，引致發言的壓力，板主應該盡量在接獲\n'
#           '      檢舉的時候才介入板面。看板檢舉一律透過<span class="hl">NBA_Picket</span>依據檢舉板板規\n'
#           ' \u3000\u3000 相關規定受理，不收私信檢舉。\n'
#           '\n'
#           'III . 一旦接獲檢舉, 板主應盡可能悉數回覆於板面累積判例建立標準.\n'
#           '\n'
#           'IV  . 遇到治安問題或爭議, 板友應直接檢舉避免回應相關文章. 即使並非\n'
#           '      始作俑者, 於回應時出現任何更多的治安問題者, 並不會酌情.\n'
#           '\n'
#           'V   . 治安問題的處理並非懲罰, 所有處理方式都以防止問題惡化和擴大作\n'
#           '      為目標. 因此, 不論是禁回, 刪文, 鎖文, 低調, 歸零, 警告, 口頭警告,\n'
#           '      還是水桶禁言, 都只是防止問題惡化的手段.\n'
#           '\n'
#           'VI  . 為避免看板公告淪為獨斷獨行, 鼓勵板友參與討論, 公告文下之違規\n'
#           '      原則從輕認定, 涉及人身攻擊者除外.\n'
#           '\n'
#           'VII . 所有判決可供討論, 錯了就改, 板主不可能做什麼都是對的. 但是參\n'
#           '      與判例討論仍需恪守板規及網路禮儀.\n'
#           '\n'
#           '\n'
#           'VIII. 慣於鑽板規灰色地帶行攻訐奚落者` 主動挑起治安事端之始作俑者\n'
#           '      認定為危險使用者, 板主會設法加以限制之.\n'
#           '\n'
#           'IX  . 非受本板治安相關原則判例與明文限定之違規, 板主盡可能善意解讀.\n'
#           '\n'
#           '<span class="f2">※3.發文/推文限制※</span>\n'
#           '\n'
#           '  1.原作者不得惡意竄改、刪除推文，必須尊重所有看板參與者之權益。\n'
#           '\n'
#           '  2.內容涉及鬧板行為之文章或推文（認定標準參考其他補充事項。)\n'
#           '    針對與內文或推文串之內容行離題、釣魚引戰、挑起球迷對立、或披露個資，\n'
#           '    若為文章則板主得劣文退回。\n'
#           '   （註：情節嚴重或大量使用時，版主可視情況加重一犯。）\n'
#           '    (以靈長類動物形容球員或動作視為3-2違規。)\n'
#           '\n'
#           '  3.不得以板面為工具，行惡意攻擊特定球員/球隊/板友之實，或挑起特定球迷間\n'
#           '    之爭端．對於遭受人身攻擊之板友，若其原言論並無爭議，則板主有權加重攻\n'
#           '    擊者之處分。\n'
#           '   （註：情節嚴重或大量使用時，板主可視情況加重一犯。\n'
#           '     <span class="f1 hl">崩潰</span>一詞，如<span class="f3 '
#           'hl">指涉球迷或板友ID，亦屬於挑起爭端之範疇。)</span>\n'
#           '<span class="f3 hl">  攻擊言論之細則如下</span>\n'
#           '\n'
#           '    硬限制(關鍵字出現即違規)：\n'
#           '\n'
#           '        (1)含有負面、惡意文字。\n'
#           '           例如：<span class="f1 hl">屎、孬、賤、渣、姦、</span>...等等。\n'
#           '\n'
#           '        (2)含負面、不雅等人、事、物。\n'
#           '            例如：<span class="f6 hl">強暴、垃圾、廢物、毒瘤、智障、低能、腦酸、無腦、腦洞、\n'
#           '</span><span class="f6 hl">                  '
#           '腦包、腦迷、腦殘、喜憨、腦癱、懶覺、龜頭(男性生殖器)、屄(女性\n'
#           '</span><span class="f6 hl">                  生殖器)</span>...等等。\n'
#           '\n'
#           '        (3)指涉私人隱私、不實指控(若經球員或官方新聞證實則不再此限)。\n'
#           '           例如：病史、醫療行為、犯罪行為...等等。\n'
#           '\n'
#           '    補充說明：\n'
#           '\n'
#           '        (1)若球員本身有相關負面要聞，則為可受公評的範圍，其下相關之暱稱可容\n'
#           '           許之。\n'
#           '\n'
#           '        (2)板眾應酌量使用，若不斷重複、蓄意使用企圖引起爭端者，板主仍會根據\n'
#           '           量來判定，而至於垃圾、廢物、懶覺等廣義以及涉及女性觀點之嚴重詞彙\n'
#           '           ，仍會無視動機以行為處理。\n'
#           '\n'
#           '        (3)「屌」與「屎」(及其他相通同音字)，板主將視其使用方式，若為口語化用法\n'
#           '           ，如「屌打」，「烙賽」，「打得像屎」等，則給予放寬。實際標準仍由板主\n'
#           '            判定，不在此述。\n'
#           '\n'
#           '  4.請勿回文公告，對公告有問題可寄信或是po文討論，違規者板主得刪文/劣退之。\n'
#           '    公告文下面推文違規，會以多一處犯規懲處。\n'
#           '\n'
#           '  5.文章內請勿使用注音文或過多簡體字，推文中如使用注音文或簡體字，超過三個字\n'
#           '    予以水桶。\n'
#           '\n'
#           '  6.於同一篇文章進行噓文達5次以上，但BOX/LIVE文不受限。\n'
#           '<span class="f1 hl">    註:以最後一噓的時間點為準。</span>\n'
#           '\n'
#           '\u30007.看板禁止未尊重板友之個板文及自介文。違規文章版主得刪文或劣文退回，\n'
#           '\n'
#           '  8.禁止重複類似論述、跳針、洗板、大量洗同主題文章數。\n'
#           '\n'
#           '  9.討論串已Ｓ者，請勿回覆，回覆者即違規，板主有權刪除之。（仍可推文討論）\n'
#           '\n'
#           ' 10.單一文章若同時犯三項以上版規（單篇文章累積三犯），則除砍除文章外，板主得退\n'
#           '\u3000\u3000文。此外，若違反站規(例如：公佈私信內容。)也比照辦理。\n'
#           '\n'
#           ' 11.以負面或者羞辱詞彙點名板友：被點名板友得至檢舉板實名檢舉，並註明違反3-11。\n'
#           '    板主群視狀況傳喚被檢舉人到案說明。\n'
#           '\n'
#           ' 12.Live/Box文規定：從寬認定，但應以場上戰況及球員表現為主，引戰與攻擊球迷\n'
#           '    或者板友，或離題行為嚴重者仍會辦理之，以質和量判定。\n'
#           '     1) 硬限制攻擊/引戰<span class="f3 hl">球迷/板友</span>：一樣罰\n'
#           '     2) 硬限制攻擊<span class="f5 '
#           'hl">球員/球隊</span>：不建議使用，少量不罰，超過一日三次，三日五\n'
#           '        次則處分。\n'
#           '\n'
#           '<span class="b1">附則</span>\n'
#           '\n'
#           '\n'
#           '\u3000<span class="f2">※1.罰則※</span>\n'
#           '<span class="f1 hl">刪除文章相關</span>\n'
#           '\n'
#           '    (1)違反板規一～三者(2)字數不足、超發者(3)錯誤發文格式者\n'
#           '\n'
#           '<span class="f1 hl">    違規次數與罰則計算</span>\n'
#           '\n'
#           '    一犯：水桶七日\n'
#           '\u3000\u3000二犯：水桶二週\n'
#           '\u3000\u3000三犯：水桶一個月\n'
#           '\u3000\u3000四犯：水桶半年\n'
#           '\u3000\u3000五犯：水桶二年\n'
#           '    五犯以上：多一犯多一年。若遇嚴重違規者，板主得處以十年水桶。\n'
#           '\u3000\u3000\u3000\n'
#           '    <span class="f1 hl">累犯次數計算方式</span>\n'
#           '\n'
#           '    違規者於上次出桶後超過三個月未違規可消除違規乙次\n'
#           '\n'
#           '    板主水桶時，若查詢到違規者上次觸犯相同板規得加重一次(累犯)。\n'
#           '\n'
#           '    <span class="f3 hl">單日處分公告之同一違規人所有違規</span>\n'
#           '\u3000\u3000\n'
#           '\u3000\u3000<span class="f3 hl">其禁言天數以當回累犯次數累加計</span>\n'
#           '\n'
#           '\u3000\u3000即初犯者如一口氣犯下三次違規即禁言  7*3 = 21日 計一犯\n'
#           '\n'
#           '    季後初犯者則是                      7*2 = 14日 計一犯\n'
#           '\u3000\n'
#           '    三犯未消者如觸犯兩次違規則禁言   半年*2 = 1年  計四犯\n'
#           '\u3000\u3000\n'
#           '  \u3000遇特殊情況，板主有權視情況調整罰則內容，但須於公告中說明．\n'
#           '\n'
#           '\n'
#           '    <span class="f1 hl">輕微違規與板規灰色地帶罰則</span>\n'
#           '\n'
#           '    為協助板主快速維持看板治安\n'
#           '\n'
#           '    本板提供兩項工具作為使用\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '    <span class="f1 hl">警告</span>\n'
#           '\n'
# ...
#           '    Jonathan Kuminga     22 $ 7.64M                   │<span '
#           'class="f3 hl">Dario Saric       (金塊)</span>\n'
#           '    Trayce Jackson-Davis 24 $ 1.89M                   │\n'
#           ' <span class="hl">C  </span>Kevon Looney         28 $ '
#           '8.00M                   │              <span class="f6 hl">#52 '
#           '(雷霆)</span>\n'
#           '                                                      │<span '
#           'class="b7"> </span><span class="f0 b7">◆ Two-Way ◆      </span>\n'
#           '                                                      │<span '
#           'class="hl">PG </span>Pat Spencer\n'
#           '                                                      │<span '
#           'class="hl">PG </span><span class="f2 hl">Reece Beekman  '
#           '(落選)</span>\n'
#           '<span class="hl">C  </span><span class="f2 hl">Quinten Post         '
#           '24       </span><span class="f6 hl">(勇士/雷霆/阿拓 #52)</span>│\n'
#           '───────────────────────────┴────────────\n'
#           '<span class="b7"> </span> 勇 <span class="b1"> </span><span '
#           'class="b1 hl">快艇 </span><span class="hl"> </span>湖 陽 王 <span '
#           'class="b7"> </span> <span class="f3 hl">簽約 </span><span class="f6 '
#           'hl">交易 </span><span class="f1 hl">續約 </span><span class="f2 hl">新秀 '
#           '</span><span class="f5 hl">選擇 </span><span class="f5 b7 hl"> '
#           '</span><span class="f5 hl"> </span><span class="f3 hl">簽約別隊 '
#           '</span><span class="f6 hl">交易走 </span><span class="f2 hl">裁掉/離隊 '
#           '</span>\n'
#           '───────────────────────────┬────────────\n'
#           '<span class="f0 b7">[Coach] Tyronn Lue       Age Salary  '
#           '★Transactions★ </span>│<span class="b7"> </span><span class="f0 '
#           'b7">◆ Free Agent ◆    </span>\n'
#           '<span class="hl">PG </span>Nah\'Shon Hyland      24 $ '
#           '4.16M                   │Brandon Boston Jr.(xRFA)\n'
#           '    <span class="f5 hl">Russell Westbrook    36 $ 4.03M    (Player '
#           'Option)</span>│<span class="f0 hl">Moussa Diabate    (2way)</span>\n'
#           '<span class="f3 hl">Kris Dunn            30 $     M    $  M/ y  '
#           '(爵士)</span>│<span class="f0 hl">Xavier Moon       (2way)</span>\n'
#           '<span class="hl">SG </span><span class="f1 hl">James Harden         '
#           '35 #33.65M    $70M/2y    (FA)</span>│\n'
#           '    Norman Powell        31 $19.24M                   │\n'
#           '    Amir Coffey          27 $ 3.94M                   │\n'
#           '    <span class="f3 hl">Kevin Porter Jr.     24 $ 2.24M  $4.78M/2y  '
#           '(火箭)</span>│\n'
#           '    <span class="f2 hl">Cam Christie         19 $ '
#           '1.16M              (#46)</span>│\n'
#           ' <span class="hl">SF </span>Kawhi Leonard        33 '
#           '$49.21M              (35%)│<span class="b7"> </span><span class="f0 '
#           'b7">◆ Out ◆        </span>\n'
#           '    Terance Mann         28 $11.42M                   │<span '
#           'class="f3 hl">Mason Plumlee     (太陽)</span>\n'
#           '<span class="f3 hl">Derrick Jones Jr.    27 $ 9.52M   $30M/3y '
#           '(獨行俠)</span>│<span class="f3 hl">Paul George       (76人)</span>\n'
#           '<span class="f3 hl">Nicolas Batum        36 $ 4.67M   $9.6M/2y  '
#           '(76人)</span>│<span class="f3 hl">Daniel Theis      (鵜鶘)</span>\n'
#           '<span class="hl">PF </span><span class="f5 hl">P.J. Tucker          '
#           '39 $11.54M    (Player Option)</span>│\n'
#           '    Kobe Brown           25 $ 2.53M                   │\n'
#           ' <span class="hl">C  </span>Ivica Zubac          27 '
#           '$11.74M                   │<span class="b7"> </span><span class="f0 '
#           'b7">◆ Two-Way ◆      </span>\n'
#           '<span class="f3 hl">Mo Bamba             26 $ 2.61M   $2.61M/1y '
#           '(76人)</span>│<span class="hl">SF </span>Jordan Miller\n'
#           '                                                      │\n'
#           ' <span class="hl">PF Kai Jones            24 Exhibit 10           '
#           '(xTO)</span>│\n'
#           '───────────────────────────┴────────────\n'
#           '<span class="b7"> </span> 勇 艇 <span class="b5"> </span><span '
#           'class="f3 b5 hl">湖人 </span><span class="f3 hl"> </span>陽 王 <span '
#           'class="b7"> </span> <span class="f3 hl">簽約 </span><span class="f6 '
#           'hl">交易 </span><span class="f1 hl">續約 </span><span class="f2 hl">新秀 '
#           '</span><span class="f5 hl">選擇 </span><span class="f5 b7 hl"> '
#           '</span><span class="f5 hl"> </span><span class="f3 hl">簽約別隊 '
#           '</span><span class="f6 hl">交易走 </span><span class="f2 hl">裁掉/離隊 '
#           '</span>\n'
#           '───────────────────────────┬────────────\n'
#           '<span class="f4 b7 hl">[Coach] JJ Redick        </span><span '
#           'class="f0 b7">Age Salary  ★Transactions★ </span>│<span class="b7"> '
#           '</span><span class="f0 b7">◆ Free Agent ◆    </span>\n'
#           '<span class="hl">PG </span><span class="f5 hl">D\'Angelo '
#           'Russell     28 $18.69M    (Player Option)</span>│Spencer Dinwiddie\n'
#           '    Jalen Hood-Schifino  21 $ 3.88M                   │<span '
#           'class="f0 hl">Skylar Mays       (2way)</span>\n'
#           '<span class="f2 hl">Bronny James         20 $ 1.16M              '
#           '(#55)</span>│<span class="f0 hl">Harry Giles III   (2way)</span>\n'
#           '<span class="hl">SG </span>Austin Reaves        26 '
#           '$12.98M                   │\n'
#           '    Gabe Vincent         28 $11.00M                   │\n'
#           '    <span class="f1 hl">Max Christie         21 $ 7.14M      '
#           '$32M/4y (RFA)</span>│\n'
#           ' <span class="hl">SF </span><span class="f1 hl">LeBron '
#           'James         40 $48.73M  $101.35M/2y (xPO)</span>│\n'
#           '    <span class="f2 hl">Dalton Knecht        23 $ '
#           '3.82M              (#17)</span>│\n'
#           '    <span class="f5 hl">Cam Reddish          25 $ 2.46M    (Player '
#           'Option)</span>│<span class="b7"> </span><span class="f0 b7">◆ Out '
#           '◆        </span>\n'
#           '    Maxwell Lewis        22 $ 1.89M                   │<span '
#           'class="f3 hl">Taurean Prince    (公鹿)</span>\n'
#           '<span class="hl">PF </span>Rui Hachimura        26 '
#           '$17.00M                   │\n'
#           '    Jarred Vanderbilt    25 $10.71M                   │\n'
#           ' <span class="hl">C  </span>Anthony Davis        31 '
#           '$43.22M                   │\n'
#           '    <span class="f5 hl">Christian Wood       29 $ 3.04M    (Player '
#           'Option)</span>│\n'
#           '    <span class="f5 hl">Jaxson Hayes         24 $ 2.46M    (Player '
#           'Option)</span>│<span class="b7"> </span><span class="f0 b7">◆ '
#           'Two-Way ◆      </span>\n'
#           '                                                      │<span '
#           'class="hl">PF </span><span class="f1 hl">Colin Castleton      '
#           '</span>\n'
#           '                                                      │<span '
#           'class="hl">SG </span><span class="f2 hl">Armel Traore   '
#           '(落選)</span>\n'
#           '                                                      │<span '
#           'class="hl">SG </span><span class="f2 hl">Blake Hinson   '
#           '(落選)</span>\n'
#           '───────────────────────────┴────────────\n'
#           '<span class="b7"> </span> 勇 艇 湖 <span class="b5"> </span><span '
#           'class="b5 hl">太陽 </span><span class="hl"> </span>王 <span '
#           'class="b7"> </span> <span class="f3 hl">簽約 </span><span class="f6 '
#           'hl">交易 </span><span class="f1 hl">續約 </span><span class="f2 hl">新秀 '
#           '</span><span class="f5 hl">選擇 </span><span class="f5 b7 hl"> '
#           '</span><span class="f5 hl"> </span><span class="f3 hl">簽約別隊 '
#           '</span><span class="f6 hl">交易走 </span><span class="f2 hl">裁掉/離隊 '
#           '</span>\n'
#           '───────────────────────────┬────────────\n'
#           '<span class="f4 b7 hl">[Coach] Mike Budenholzer </span><span '
#           'class="f0 b7">Age Salary  ★Transactions★ </span>│<span class="b7"> '
#           '</span><span class="f0 b7">◆ Free Agent ◆    </span>\n'
#           '<span class="hl">PG </span><span class="f3 hl">Monte Morris         '
#           '29 $ 2.80M    $2.8M/1y (灰狼)</span>│Thaddeus Young\n'
#           ' <span class="hl">SG </span>Bradley Beal         31 '
#           '$50.20M                   │Isaiah Thomas\n'
#           '    Devin Booker         28 $49.21M              (35%)│<span '
#           'class="f0 hl">Udoka Azubuike    (2way)</span>\n'
#           '<span class="f1 hl">Grayson Allen        29 $15.63M     $70M/4y '
#           '(延長)</span>│<span class="f0 hl">Saben Lee         (2way)</span>\n'
#           '<span class="f1 hl">Josh Okogie          26 $ 7.69M     $16M/2y  '
#           '(xPO)</span>│<span class="f0 hl">Ish Wainright     (2way)</span>\n'
#           '<span class="f1 hl">Damion Lee           32 $ 2.80M    $2.8M/1y  '
#           '(xPO)</span>│\n'
#           ' <span class="hl">SF </span>Kevin Durant         36 '
#           '$51.18M                   │\n'
#           '    <span class="f1 hl">Royce O\'Neale        31 $ 9.82M     '
#           '$44M/4y   (FA)</span>│<span class="b7"> </span><span class="f0 '
#           'b7">◆ Out ◆        </span>\n'
#           '    Nassir Little        24 $ 6.75M                   │<span '
#           'class="f3 hl">Eric Gordon       (76人)</span>\n'
#           '<span class="f2 hl">Ryan Dunn            22 $ 2.53M         '
#           '</span><span class="f6 hl">(金塊 #28)</span>│<span class="f3 hl">Drew '
#           'Eubanks      (爵士)</span>\n'
#           '<span class="hl">PF </span>David Roddy          23 $ '
#           '2.85M                   │\n'
#           '    <span class="f1 hl">Bol Bol              24 $ 2.92M   '
#           '$2.92M/1y   (FA)</span>│\n'
#           ' <span class="hl">C  </span>Jusuf Nurkic         30 '
#           '$18.13M                   │\n'
#           '    <span class="f3 hl">Mason Plumlee        34 $ 3.30M    $3.3M/1y '
#           '(快艇)</span>│ <span class="f6 hl">#22 (金塊)   #56 (尼克)</span>\n'
#           '<span class="f2 hl">Oso Ighodaro         22 $ 1.16M  </span><span '
#           'class="f6 hl">(拓荒者/雷霆 #40)</span>│<span class="b7"> </span><span '
#           'class="f0 b7">◆ Two-Way ◆      </span>\n'
#           '                                                      │<span '
#           'class="hl">SF </span><span class="f2 hl">Jalen Bridges  '
#           '(落選)</span>\n'
#           '                                                      │<span '
#           'class="hl">PG Collin Gillespie (金)</span>\n'
#           '                                                      │\n'
#           '───────────────────────────┴────────────\n'
#           '<span class="b7"> </span> 勇 艇 湖 陽 <span class="b4"> </span><span '
#           'class="b4 hl">國王 </span><span class="hl"> </span><span class="b7 '
#           'hl"> </span><span class="hl"> </span><span class="f3 hl">簽約 '
#           '</span><span class="f6 hl">交易 </span><span class="f1 hl">續約 '
#           '</span><span class="f2 hl">新秀 </span><span class="f5 hl">選擇 '
#           '</span><span class="f5 b7 hl"> </span><span class="f5 hl"> '
#           '</span><span class="f3 hl">簽約別隊 </span><span class="f6 hl">交易走 '
#           '</span><span class="f2 hl">裁掉/離隊 </span>\n'
#           '───────────────────────────┬────────────\n'
#           '<span class="f0 b7">[Coach] Mike Brown       Age Salary  '
#           '★Transactions★ </span>│<span class="b7"> </span><span class="f0 '
#           'b7">◆ Free Agent ◆    </span>\n'
#           '<span class="hl">PG </span>De\'Aaron Fox         27 '
#           '$34.85M                   │JaVale McGee\n'
#           '    <span class="f2 hl">Devin Carter         22 $ '
#           '4.69M              (#13)</span>│Kessler Edwards   (xRFA)\n'
#           '    <span class="f3 hl">Jordan McLaughlin    28 $ 2.42M   $2.42M/1y '
#           '(灰狼)</span>│<span class="f0 hl">Jalen Slawson     (2way)</span>\n'
#           '<span class="hl">SG </span><span class="f1 hl">Malik Monk           '
#           '26 $17.41M     $78M/4y   (FA)</span>│<span class="f0 hl">Jordan '
#           'Ford       (2way)</span>\n'
#           '    Kevin Huerter        26 $16.83M                   │\n'
#           '    Colby Jones          22 $ 2.12M                   │\n'
#           ' <span class="hl">SF </span><span class="f6 hl">DeMar '
#           'DeRozan        35 $24.13M     $76M/3y (公牛)</span>│\n'
#           '    <span class="f6 hl">Jalen McDaniels      27 $ 4.74M             '
#           '(暴龍)</span>│<span class="b7"> </span><span class="f0 b7">◆ Out '
#           '◆        </span>\n'
#           '    Keon Ellis           25 $ 2.12M                   │<span '
#           'class="f6 hl">Davion Mitchell   (暴龍)</span>\n'
#           '<span class="hl">PF </span>Keegan Murray        24 $ '
#           '8.81M                   │<span class="f6 hl">Sasha Vezenkov    '
#           '(暴龍)</span>\n'
#           '    Trey Lyles           29 $ 8.00M                   │<span '
#           'class="f6 hl">Harrison Barnes   (馬刺)</span>\n'
#           '<span class="hl">C  </span>Domantas Sabonis     28 '
#           '$41.80M                   │<span class="f6 hl">Chris Duarte      '
#           '(公牛)</span>\n'
#           '<span class="f1 hl">Alex Len             31 $ 3.30M    $3.3M/1y   '
#           '(FA)</span>│\n'
#           '                                                      '
#           '│              <span class="f6 hl">#45 (暴龍)</span>\n'
#           '                                                      │<span '
#           'class="b7"> </span><span class="f0 b7">◆ Two-Way ◆      </span>\n'
#           '                                                      │<span '
#           'class="hl">SG </span>Mason Jones\n'
#           '                                                      │<span '
#           'class="hl">SF </span><span class="f2 hl">Isaiah '
#           'Crawford(落選)</span>\n'
#           '                                                      │\n'
#           '───────────────────────────┴────────────\n'
#           '\n'
#           '\n'
#           '--\n'
#           '<span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 123.241.68.56 (臺灣)\n'
#           '</span><span class="f2">※ 文章網址: <a '
#           'href="https://www.ptt.cc/bbs/NBA/M.1719733116.A.819.html" '
#           'rel="noreferrer noopener nofollow" '
#           'target="_blank">https://www.ptt.cc/bbs/NBA/M.1719733116.A.819.html</a>\n'
#           '</span>   有好老闆就有鈔能力\n'
#           '\n'
#           '   小弟已經退休了, 但一輩子支持我湖沒問題\n'
#           '\n'
#           '   免客氣\n'
#           '\n'
#           '   76人全員逃走中\n'
#           '\n'
#           '   Paul Reed 是非保障約, 不是TO.  若後續被裁掉也會標示 waived\n'
#           '\n'
#           '   好說好說\n'
#           '\n'
#           '   開市之前只剩3人, 打33都湊不滿, 遙望我湖當初的AD/LBJ/Kuzma\n'
#           '\n'
#           '   感謝補充, 已更新!\n'
#           '\n'
#           '   把 Maxey 補回來, 有給QO 應該是要留隊才是\n'
#           '\n'
#           '   客官歡迎常來\n'
#           '\n'
#           '   感謝推文, 已更新\n'
#           '\n'
#           '   靠譜\n'
#           '\n'
#           '   貧窮限制我們的想像\n'
#           '\n'
#           '   推推\n'
#           '\n'
#           '   橋家軍是你?\n'
#           '\n'
#           '   那是一定\n'
#           '\n'
#           '   讓子彈飛一會兒\n'
#           '\n'
#           '   老闆看到打進西冠覺得龍心大悅嗎\n'
#           '\n'
#           '   可是你是箭頭\n'
#           '\n'
#           '   $$$$$$ 休賽季王者你敢嘴\n'
#           '\n'
#           '   可以去查一下BBR, Murray 83%時間打SF, Barnes 90%時間打PF\n'
#           '\n'
#           '   大工程沒錯\n'
#           '\n'
#           '   請執行每日任務\n'
#           '\n'
#           '   感恩, 已修正!\n'
#           '\n'
#           '   請用力推\n'
#           '\n'
#           '   感謝2位, 已更新\n'
#           '\n'
#           '   4神湯經驗老道\n'
#           '\n'
#           '<span class="f2">※ 編輯: laigei (180.177.111.31 臺灣), 07/14/2024 '
#           '15:25:56\n'
#           '</span>',
#   'link': 'https://www.ptt.cc/bbs/NBA/M.1719733116.A.819.html',
#   'title': '[情報] 2024-25 自由市場 球隊異動表格 (7/14)'}]

# %%
# 清空放置列表資訊的變數
list_posts.clear()

#起始頁數
init_page = 6503

#最新頁數
latest_page = 6504

# 在已經知道分頁數的情況下
for page in range(init_page, latest_page + 1 ):

    # 取得新聞列表
    url = f"https://www.ptt.cc/bbs/NBA/index(page).html"

    # 用 requests 的 get 方法把網頁抓下來
    res = req.get(url)

    # 指定 lxml 作為解析器
    soup = bs(res.text, "lxml")

    # 取得 列表 的文字與超連結
    for a in soup.select('div.r-ent div.title a[href]'):
        # 加入列表資訊
        list_posts.append({
            'title': a.get_text(),
            'link': 'https://www.ptt.cc' + a['href']
        })

# 走訪每一個 a link，整合網頁內文
for index, obj in enumerate(list_posts):
    res_ = req.get(obj['link'])
    soup_ = bs(res_.text, "lxml")

    # 去掉 div.article-metaline (作者、標題、時間…等)
    for div in soup_.select('div[class^="article-metaline"]'):
        div.decompose()

    # 去掉 div.push (推文: 推、→、噓) (判斷去掉元素是否存在)
    if len( soup_.select('div.push') ) > 0:
        for div in soup_.select('div.push'):
            div.decompose()

    # 取得實際需要的內容 (類似 JavaScript 的 innerHTML)
    html = soup_.select_one('div#main-content').decode_contents()

    # 整合到列表資訊的變數當中
    list_posts[index]['html'] = html

# 預覽所有結果
pprint(list_posts)
# Out:
# []
